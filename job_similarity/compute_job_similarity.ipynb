# %% [markdown]
# # Job Similarity - How Similar are two jobs?

# %% [markdown]
# ### Load libraries

# %%
import os
import json
import tqdm
import re
import string
import nltk
from nltk import word_tokenize, FreqDist
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.porter import PorterStemmer
from sklearn.metrics.pairwise import cosine_similarity
import spacy
import scipy
import numpy as np
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

import warnings
warnings.filterwarnings('ignore')

# %%
#nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ### Read data

# %%
df_ori = pd.read_csv('../data/data job posts.csv')
df_ori.head()
print(df_ori.shape)
df = df_ori.drop_duplicates(['jobpost','Title'])
print(df.shape)
print("Removed {0} duplicates (based on jobpost + Title)".format(df_ori.shape[0]-df.shape[0]))
# Out:
# (19001, 24)
# (18892, 24)
# Removed 109 duplicates (based on jobpost + Title)

# %%
df.head()
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\nJOB TITL...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\nJOB...   Jan 7, 2004
# 3  Manoff Group\nJOB TITLE:  BCC Specialist\nPOSI...   Jan 7, 2004
# 4  Yerevan Brandy Company\nJOB TITLE:  Software D...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# 2        Caucasus Environmental NGO Network (CENN)              NaN  NaN
# 3                                     Manoff Group              NaN  NaN
# 4                           Yerevan Brandy Company              NaN  NaN
#
#   Eligibility Audience StartDate                             Duration  \
# 0         NaN      NaN       NaN                                  NaN
# 1         NaN      NaN       NaN                             3 months
# 2         NaN      NaN       NaN  Renewable annual contract\nPOSITION
# 3         NaN      NaN       NaN                                  NaN
# 4         NaN      NaN       NaN                                  NaN
#
#                                             Location  \
# 0                                   Yerevan, Armenia
# 1  IREX Armenia Main Office; Yerevan, Armenia \nD...
# 2                                   Yerevan, Armenia
# 3                                Manila, Philippines
# 4                                   Yerevan, Armenia
#
#                                       JobDescription  \
# 0  AMERIA Investment Consulting Company is seekin...
# 1                                                NaN
# 2  Public outreach and strengthening of a growing...
# 3  The LEAD (Local Enhancement and Development fo...
# 4                                                NaN
#
#                                        JobRequirment  \
# 0  - Supervises financial management and administ...
# 1                                                NaN
# 2  - Working with the Country Director to provide...
# 3  - Identify gaps in knowledge and overseeing in...
# 4  - Rendering technical assistance to Database M...
#
#                                         RequiredQual Salary  \
# 0  To perform this job successfully, an\nindividu...    NaN
# 1  - Bachelor's Degree; Master's is preferred;\n-...    NaN
# 2  - Degree in environmentally related field, or ...    NaN
# 3  - Advanced degree in public health, social sci...    NaN
# 4  - University degree; economical background is ...    NaN
#
#                                         ApplicationP OpeningDate  \
# 0  To apply for this position, please submit a\nc...         NaN
# 1  Please submit a cover letter and resume to:\nI...         NaN
# 2  Please send resume or CV toursula.kazarian@......         NaN
# 3  Please send cover letter and resume to Amy\nPe...         NaN
# 4  Successful candidates should submit\n- CV; \n-...         NaN
#
#                                       Deadline Notes  \
# 0                              26 January 2004   NaN
# 1                              12 January 2004   NaN
# 2  20 January 2004\nSTART DATE:  February 2004   NaN
# 3      23 January 2004\nSTART DATE:  Immediate   NaN
# 4                       20 January 2004, 18:00   NaN
#
#                                               AboutC Attach  Year  Month  \
# 0                                                NaN    NaN  2004      1
# 1  The International Research & Exchanges Board (...    NaN  2004      1
# 2  The Caucasus Environmental NGO Network is a\nn...    NaN  2004      1
# 3                                                NaN    NaN  2004      1
# 4                                                NaN    NaN  2004      1
#
#       IT
# 0  False
# 1  False
# 2  False
# 3  False
# 4   True

# %% [markdown]
# ### Filter selective columns

# %%
df_job_related = df[['Title','JobDescription','RequiredQual','JobRequirment']]

# %%
df_job_related.head(10)
# Out:
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
# 5                                         Saleswoman
# 6                Chief Accountant/ Finance Assistant
# 7     Non-paid part or full time Programmatic Intern
# 8                     Assistant to Managing Director
# 9              Program Assistant (INL), FSN-8; FP-6*
#
#                                       JobDescription  \
# 0  AMERIA Investment Consulting Company is seekin...
# 1                                                NaN
# 2  Public outreach and strengthening of a growing...
# 3  The LEAD (Local Enhancement and Development fo...
# 4                                                NaN
# 5     Saleswoman will sell menswear and accessories.
# 6  The Armenian Branch Office of the Open Society...
# 7                                                NaN
# 8                                                NaN
# 9  The incumbent assists in coordinating INL-fund...
#
#                                         RequiredQual  \
# 0  To perform this job successfully, an\nindividu...
# 1  - Bachelor's Degree; Master's is preferred;\n-...
# 2  - Degree in environmentally related field, or ...
# 3  - Advanced degree in public health, social sci...
# 4  - University degree; economical background is ...
# 5  - Candidates should be female, 20-30 years old...
# 6  - University degree in finance/ accounting; \n...
# 7                                                NaN
# 8  - University degree;\n- At least 3 years of ex...
# 9  NOTE: All applicants are instructed to\naddres...
#
#                                        JobRequirment
# 0  - Supervises financial management and administ...
# 1                                                NaN
# 2  - Working with the Country Director to provide...
# 3  - Identify gaps in knowledge and overseeing in...
# 4  - Rendering technical assistance to Database M...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  - Coordinating the work of subordinate employe...
# 9                                                NaN

# %%
df_job_related['JobDescription'] = df_job_related['JobDescription'].astype(str)
df_job_related['RequiredQual'] = df_job_related['RequiredQual'].astype(str)
df_job_related['JobRequirment'] = df_job_related['JobRequirment'].astype(str)
df_job_related['Title'] = df_job_related['Title'].astype(str)

# %%
df_job_related['JobDescription_token'] = df_job_related['JobDescription'].map(word_tokenize)
df_job_related['RequiredQual_token'] = df_job_related['RequiredQual'].map(word_tokenize)
df_job_related['JobRequirment_token'] = df_job_related['JobRequirment'].map(word_tokenize)

# %% [markdown]
# #### Remove punctuations and stopwords from the above tokens

# %%
# stopwords and punctuation removal
df_job_related['JobDescription_token'] = df_job_related['JobDescription_token'].apply(lambda x: [item for item in x if item not in stop_words])
df_job_related['JobDescription_token'] = df_job_related['JobDescription_token'].apply(lambda x: [item for item in x if item not in string.punctuation])
df_job_related['RequiredQual_token'] = df_job_related['RequiredQual_token'].apply(lambda x: [item for item in x if item not in stop_words])
df_job_related['RequiredQual_token'] = df_job_related['RequiredQual_token'].apply(lambda x: [item for item in x if item not in string.punctuation])
df_job_related['JobRequirment_token'] = df_job_related['JobRequirment_token'].apply(lambda x: [item for item in x if item not in stop_words])
df_job_related['JobRequirment_token'] = df_job_related['JobRequirment_token'].apply(lambda x: [item for item in x if item not in string.punctuation])

# %%
# lowercase
df_job_related['JobDescription_token'] = df_job_related['JobDescription_token'].apply(lambda x: [item.lower() for item in x])
df_job_related['RequiredQual_token'] = df_job_related['RequiredQual_token'].apply(lambda x: [item.lower() for item in x])
df_job_related['JobRequirment_token'] = df_job_related['JobRequirment_token'].apply(lambda x: [item.lower() for item in x])

# %%
# stem
df_job_related['JobDescription_token'] = df_job_related['JobDescription_token'].apply(lambda x: [PorterStemmer().stem(item) for item in x])
df_job_related['RequiredQual_token'] = df_job_related['RequiredQual_token'].apply(lambda x: [PorterStemmer().stem(item) for item in x])
df_job_related['JobRequirment_token'] = df_job_related['JobRequirment_token'].apply(lambda x: [PorterStemmer().stem(item) for item in x])

# %%
# convert list to string
df_job_related['JobDescription_token_str'] = df_job_related['JobDescription_token'].apply(lambda x: " ".join(x))
df_job_related['RequiredQual_token_str'] = df_job_related['RequiredQual_token'].apply(lambda x: " ".join(x))
df_job_related['JobRequirment_token_str'] = df_job_related['JobRequirment_token'].apply(lambda x: " ".join(x))

# %%
df_job_related.head(10)
# Out:
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
# 5                                         Saleswoman
# 6                Chief Accountant/ Finance Assistant
# 7     Non-paid part or full time Programmatic Intern
# 8                     Assistant to Managing Director
# 9              Program Assistant (INL), FSN-8; FP-6*
#
#                                       JobDescription  \
# 0  AMERIA Investment Consulting Company is seekin...
# 1                                                nan
# 2  Public outreach and strengthening of a growing...
# 3  The LEAD (Local Enhancement and Development fo...
# 4                                                nan
# 5     Saleswoman will sell menswear and accessories.
# 6  The Armenian Branch Office of the Open Society...
# 7                                                nan
# 8                                                nan
# 9  The incumbent assists in coordinating INL-fund...
#
#                                         RequiredQual  \
# 0  To perform this job successfully, an\nindividu...
# 1  - Bachelor's Degree; Master's is preferred;\n-...
# 2  - Degree in environmentally related field, or ...
# 3  - Advanced degree in public health, social sci...
# 4  - University degree; economical background is ...
# 5  - Candidates should be female, 20-30 years old...
# 6  - University degree in finance/ accounting; \n...
# 7                                                nan
# 8  - University degree;\n- At least 3 years of ex...
# 9  NOTE: All applicants are instructed to\naddres...
#
#                                        JobRequirment  \
# 0  - Supervises financial management and administ...
# 1                                                nan
# 2  - Working with the Country Director to provide...
# 3  - Identify gaps in knowledge and overseeing in...
# 4  - Rendering technical assistance to Database M...
# 5                                                nan
# 6                                                nan
# 7                                                nan
# 8  - Coordinating the work of subordinate employe...
# 9                                                nan
#
#                                 JobDescription_token  \
# 0  [ameria, invest, consult, compani, seek, chief...
# 1                                              [nan]
# 2  [public, outreach, strengthen, grow, network, ...
# 3  [the, lead, local, enhanc, develop, health, bc...
# 4                                              [nan]
# 5            [saleswoman, sell, menswear, accessori]
# 6  [the, armenian, branch, offic, open, societi, ...
# 7                                              [nan]
# 8                                              [nan]
# 9  [the, incumb, assist, coordin, inl-fund, law, ...
#
#                                   RequiredQual_token  \
# 0  [to, perform, job, success, individu, must, ab...
# 1  [bachelor, 's, degre, master, 's, prefer, exce...
# 2  [degre, environment, relat, field, 5, year, re...
# 3  [advanc, degre, public, health, social, scienc...
# 4  [univers, degre, econom, background, plu, exce...
# 5  [candid, femal, 20-30, year, old, nice-look, e...
# 6  [univers, degre, finance/, account, one, year,...
# 7                                              [nan]
# 8  [univers, degre, at, least, 3, year, experi, r...
# 9  [note, all, applic, instruct, address, select,...
#
#                                  JobRequirment_token  \
# 0  [supervis, financi, manag, administr, staff, i...
# 1                                              [nan]
# 2  [work, countri, director, provid, environment,...
# 3  [identifi, gap, knowledg, overse, inform, coll...
# 4  [render, technic, assist, databas, manag, syst...
# 5                                              [nan]
# 6                                              [nan]
# 7                                              [nan]
# 8  [coordin, work, subordin, employe, maintain, l...
# 9                                              [nan]
#
#                             JobDescription_token_str  \
# 0  ameria invest consult compani seek chief finan...
# 1                                                nan
# 2  public outreach strengthen grow network enviro...
# 3  the lead local enhanc develop health bcc speci...
# 4                                                nan
# 5                 saleswoman sell menswear accessori
# 6  the armenian branch offic open societi institu...
# 7                                                nan
# 8                                                nan
# 9  the incumb assist coordin inl-fund law enforc ...
#
#                               RequiredQual_token_str  \
# 0  to perform job success individu must abl perfo...
# 1  bachelor 's degre master 's prefer excel skill...
# 2  degre environment relat field 5 year relev exp...
# 3  advanc degre public health social scienc commu...
# 4  univers degre econom background plu excel know...
# 5  candid femal 20-30 year old nice-look exterior...
# 6  univers degre finance/ account one year minimu...
# 7                                                nan
# 8  univers degre at least 3 year experi relev fie...
# 9  note all applic instruct address select criter...
#
#                              JobRequirment_token_str  \
# 0  supervis financi manag administr staff includ ...
# 1                                                nan
# 2  work countri director provid environment infor...
# 3  identifi gap knowledg overse inform collect fi...
# 4  render technic assist databas manag system rea...
# 5                                                nan
# 6                                                nan
# 7                                                nan
# 8  coordin work subordin employe maintain liaison...
# 9                                                nan
#
#                                RequiredQual_keywords
# 0  essential duty accepted accounting principles ...
# 1  Excellent skills Armenian languages Armenian t...
# 2  related field relevant experience written flue...
# 3  Advanced degree public health social science r...
# 4  economical background Excellent knowledge year...
# 5  looking exterior Excellent communication skill...
# 6  year minimum experience year minimum experienc...
# 7
# 8  years of experience relevant field office work...
# 9  selection criterion comprehensive information ...

# %% [markdown]
# ### TF-IDF based similarity

# %%
tfidf_model = TfidfVectorizer()
Title_tfidf = tfidf_model.fit_transform(df_job_related['Title'])
JobDescription_tfidf = tfidf_model.fit_transform(df_job_related['JobDescription_token_str'])
RequiredQual_tfidf = tfidf_model.fit_transform(df_job_related['RequiredQual_token_str'])
JobRequirment_tfidf = tfidf_model.fit_transform(df_job_related['JobRequirment_token_str'])

# %%
def find_similar_jobs_tfidf(index, top_n = 5):
    Title_tfidf_cosine = cosine_similarity(Title_tfidf[index:index+1], Title_tfidf).flatten()
    JobDescription_tfidf_cosine = cosine_similarity(JobDescription_tfidf[index:index+1], JobDescription_tfidf).flatten()
    RequiredQual_tfidf_cosine = cosine_similarity(RequiredQual_tfidf[index:index+1], RequiredQual_tfidf).flatten()
    JobRequirment_tfidf_cosine = cosine_similarity(JobRequirment_tfidf[index:index+1], JobRequirment_tfidf).flatten()

    average_cosine = (Title_tfidf_cosine + JobDescription_tfidf_cosine + RequiredQual_tfidf_cosine + JobRequirment_tfidf_cosine) / 4.0
    related_docs_indices = [i for i in average_cosine.argsort()[::-1] if i != index]
    return [(index, average_cosine[index]) for index in related_docs_indices][0:top_n]

# %%
df_job_related.iloc[0]
# Out:
# Title                                                 Chief Financial Officer
# JobDescription              AMERIA Investment Consulting Company is seekin...
# RequiredQual                To perform this job successfully, an\nindividu...
# JobRequirment               - Supervises financial management and administ...
# JobDescription_token        [ameria, invest, consult, compani, seek, chief...
# RequiredQual_token          [to, perform, job, success, individu, must, ab...
# JobRequirment_token         [supervis, financi, manag, administr, staff, i...
# JobDescription_token_str    ameria invest consult compani seek chief finan...
# RequiredQual_token_str      to perform job success individu must abl perfo...
# JobRequirment_token_str     supervis financi manag administr staff includ ...
# Name: 0, dtype: object

# %%
for index, score in find_similar_jobs_tfidf(0):
    print(df_job_related.iloc[index])
    print("SIMILARITY SCORE: ", score)
# Out:
# Title                                                 Chief Financial Officer
# JobDescription              River Island is seeking a Chief Financial Offi...
# RequiredQual                - Master's degree in Management, Finance or Ec...
# JobRequirment               - Develop tools and systems to provide critica...
# JobDescription_token        [river, island, seek, chief, financi, offic, r...
# RequiredQual_token          [master, 's, degre, manag, financ, econom, at,...
# JobRequirment_token         [develop, tool, system, provid, critic, financ...
# JobDescription_token_str    river island seek chief financi offic respons ...
# RequiredQual_token_str      master 's degre manag financ econom at least 5...
# JobRequirment_token_str     develop tool system provid critic financi oper...
# Name: 11223, dtype: object
# SIMILARITY SCORE:  0.4898332490345752
# Title                                                 Chief Financial Officer
# JobDescription              Armenian Datacom Company (ADC) is seeking a hi...
# RequiredQual                - Master's degree in Accounting, Finance;\n- 5...
# JobRequirment               Responsibilities include but are not limited t...
# JobDescription_token        [armenian, datacom, compani, adc, seek, highli...
# RequiredQual_token          [master, 's, degre, account, financ, 5-7, year...
# JobRequirment_token         [respons, includ, limit, assist, perform, fina...
# JobDescription_token_str    armenian datacom compani adc seek highli motiv...
# RequiredQual_token_str      master 's degre account financ 5-7 year financ...
# JobRequirment_token_str     respons includ limit assist perform financi ta...
# Name: 8319, dtype: object
# SIMILARITY SCORE:  0.4888444070679447
# Title                                                 Chief Financial Officer
# JobDescription              The Chief Financial Officer (CFO) will support...
# RequiredQual                - Degree in Accounting, Finance, Business, Law...
# JobRequirment               Financial management of the NSRCIP T1 & T2 pro...
# JobDescription_token        [the, chief, financi, offic, cfo, support, chi...
# RequiredQual_token          [degre, account, financ, busi, law, public, ad...
# JobRequirment_token         [financi, manag, nsrcip, t1, t2, project, prep...
# JobDescription_token_str    the chief financi offic cfo support chief exec...
# RequiredQual_token_str      degre account financ busi law public administr...
# JobRequirment_token_str     financi manag nsrcip t1 t2 project prepar pfr ...
# Name: 12368, dtype: object
# SIMILARITY SCORE:  0.48082897033404925
# Title                                                 Chief Financial Officer
# JobDescription              Gritti LLC is inviting highly qualified\nprofe...
# RequiredQual                - Master's or equivalent university degree in ...
# JobRequirment               General Responsibilities:   \n- Assist in perf...
# JobDescription_token        [gritti, llc, invit, highli, qualifi, professi...
# RequiredQual_token          [master, 's, equival, univers, degre, financ, ...
# JobRequirment_token         [gener, respons, assist, perform, task, necess...
# JobDescription_token_str    gritti llc invit highli qualifi profession ful...
# RequiredQual_token_str      master 's equival univers degre financ account...
# JobRequirment_token_str     gener respons assist perform task necessari ac...
# Name: 8120, dtype: object
# SIMILARITY SCORE:  0.47371388854146607
# Title                                           Chief Financial Officer (CFO)
# JobDescription              The CFO will have full authority and responsib...
# RequiredQual                - Master's degree in Business Administration, ...
# JobRequirment               - Ensure compliance and deal with local, state...
# JobDescription_token        [the, cfo, full, author, respons, establish, m...
# RequiredQual_token          [master, 's, degre, busi, administr, financ, a...
# JobRequirment_token         [ensur, complianc, deal, local, state, tax, fi...
# JobDescription_token_str    the cfo full author respons establish mean man...
# RequiredQual_token_str      master 's degre busi administr financ account ...
# JobRequirment_token_str     ensur complianc deal local state tax financ re...
# Name: 5844, dtype: object
# SIMILARITY SCORE:  0.4647738182331448

# %%
df_job_related.iloc[1]
# Out:
# Title                       Full-time Community Connections Intern (paid i...
# JobDescription                                                            nan
# RequiredQual                - Bachelor's Degree; Master's is preferred;\n-...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [bachelor, 's, degre, master, 's, prefer, exce...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      bachelor 's degre master 's prefer excel skill...
# JobRequirment_token_str                                                   nan
# Name: 1, dtype: object

# %%
for index, score in find_similar_jobs_tfidf(1):
    print(df_job_related.iloc[index])
    print("SIMILARITY SCORE: ", score)
# Out:
# Title                                                 IT Teacher  (full time)
# JobDescription                                                            nan
# RequiredQual                - Degree in Computer Science, Information Tech...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [degre, comput, scienc, inform, technolog, rel...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      degre comput scienc inform technolog relat dis...
# JobRequirment_token_str                                                   nan
# Name: 114, dtype: object
# SIMILARITY SCORE:  0.6631658107959908
# Title                       Non-paid part or full time Administrative Intern
# JobDescription                                                           nan
# RequiredQual                                                             nan
# JobRequirment                                                            nan
# JobDescription_token                                                   [nan]
# RequiredQual_token                                                     [nan]
# JobRequirment_token                                                    [nan]
# JobDescription_token_str                                                 nan
# RequiredQual_token_str                                                   nan
# JobRequirment_token_str                                                  nan
# Name: 11, dtype: object
# SIMILARITY SCORE:  0.6341171085548505
# Title                                  Administrative and Programmatic Intern
# JobDescription                                                            nan
# RequiredQual                - Fluency in English and Armenian;\n- Good com...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [fluenci, english, armenian, good, commun, ski...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      fluenci english armenian good commun skill abi...
# JobRequirment_token_str                                                   nan
# Name: 127, dtype: object
# SIMILARITY SCORE:  0.6269758043940998
# Title                                  Administrative and Programmatic Intern
# JobDescription                                                            nan
# RequiredQual                - Fluency in English and Armenian;\n- Good com...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [fluenci, english, armenian, good, commun, ski...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      fluenci english armenian good commun skill abi...
# JobRequirment_token_str                                                   nan
# Name: 125, dtype: object
# SIMILARITY SCORE:  0.6269758043940998
# Title                       Non-paid part or full time Programmatic Intern
# JobDescription                                                         nan
# RequiredQual                                                           nan
# JobRequirment                                                          nan
# JobDescription_token                                                 [nan]
# RequiredQual_token                                                   [nan]
# JobRequirment_token                                                  [nan]
# JobDescription_token_str                                               nan
# RequiredQual_token_str                                                 nan
# JobRequirment_token_str                                                nan
# Name: 7, dtype: object
# SIMILARITY SCORE:  0.6259732089860925

# %%
df_job_related.iloc[2]
# Out:
# Title                                                     Country Coordinator
# JobDescription              Public outreach and strengthening of a growing...
# RequiredQual                - Degree in environmentally related field, or ...
# JobRequirment               - Working with the Country Director to provide...
# JobDescription_token        [public, outreach, strengthen, grow, network, ...
# RequiredQual_token          [degre, environment, relat, field, 5, year, re...
# JobRequirment_token         [work, countri, director, provid, environment,...
# JobDescription_token_str    public outreach strengthen grow network enviro...
# RequiredQual_token_str      degre environment relat field 5 year relev exp...
# JobRequirment_token_str     work countri director provid environment infor...
# Name: 2, dtype: object

# %%
for index, score in find_similar_jobs_tfidf(2):
    print(df_job_related.iloc[index])
    print("SIMILARITY SCORE: ", score)
# Out:
# Title                                           Country Coordinator - Armenia
# JobDescription              CENN - Caucasus Environmental NGO Network - is...
# RequiredQual                1. Education: University education in environm...
# JobRequirment               -  Write first hand articles, conduct intervie...
# JobDescription_token        [cenn, caucasu, environment, ngo, network, loo...
# RequiredQual_token          [1, educ, univers, educ, environment, scienc, ...
# JobRequirment_token         [write, first, hand, articl, conduct, intervie...
# JobDescription_token_str    cenn caucasu environment ngo network look coun...
# RequiredQual_token_str      1 educ univers educ environment scienc relat f...
# JobRequirment_token_str     write first hand articl conduct interview coll...
# Name: 404, dtype: object
# SIMILARITY SCORE:  0.45858797345562224
# Title                                                     Country Coordinator
# JobDescription              Veya Limited needs an experienced Business Man...
# RequiredQual                - University degree in Middle East Studies, In...
# JobRequirment               - Coordinate activities of the office and staf...
# JobDescription_token        [veya, limit, need, experienc, busi, manag, co...
# RequiredQual_token          [univers, degre, middl, east, studi, intern, a...
# JobRequirment_token         [coordin, activ, offic, staff, middl, east, co...
# JobDescription_token_str    veya limit need experienc busi manag coordin s...
# RequiredQual_token_str      univers degre middl east studi intern affair b...
# JobRequirment_token_str     coordin activ offic staff middl east countri e...
# Name: 13497, dtype: object
# SIMILARITY SCORE:  0.29600227041847776
# Title                                               Environmental Coordinator
# JobDescription              The Environmental Coordinator performs a\ncros...
# RequiredQual                - Higher education in Economics, Technical fie...
# JobRequirment               - Organize Environmental Committee meetings, c...
# JobDescription_token        [the, environment, coordin, perform, cross-sec...
# RequiredQual_token          [higher, educ, econom, technic, field, ecolog,...
# JobRequirment_token         [organ, environment, committe, meet, coordin, ...
# JobDescription_token_str    the environment coordin perform cross-sect fun...
# RequiredQual_token_str      higher educ econom technic field ecolog experi...
# JobRequirment_token_str     organ environment committe meet coordin superv...
# Name: 10789, dtype: object
# SIMILARITY SCORE:  0.27958412876336625
# Title                                                     Country Coordinator
# JobDescription              Veya Ltd. is looking for a qualified Country\n...
# RequiredQual                - At least 5 years of experience in project ma...
# JobRequirment               - Negotiate with potential customers;\n- Lobby...
# JobDescription_token        [veya, ltd., look, qualifi, countri, coordin, ...
# RequiredQual_token          [at, least, 5, year, experi, project, manag, e...
# JobRequirment_token         [negoti, potenti, custom, lobbi, support, proj...
# JobDescription_token_str    veya ltd. look qualifi countri coordin he/ abl...
# RequiredQual_token_str      at least 5 year experi project manag except ne...
# JobRequirment_token_str     negoti potenti custom lobbi support project co...
# Name: 18907, dtype: object
# SIMILARITY SCORE:  0.2727622198362754
# Title                                                               Volunteer
# JobDescription              We are seeking university students/ recent gra...
# RequiredQual                - Fluency in Armenian, Russian and English\n- ...
# JobRequirment               - Assist CENN Armenia Country Coordinator with...
# JobDescription_token        [we, seek, univers, students/, recent, graduat...
# RequiredQual_token          [fluenci, armenian, russian, english, good, co...
# JobRequirment_token         [assist, cenn, armenia, countri, coordin, admi...
# JobDescription_token_str    we seek univers students/ recent graduat energ...
# RequiredQual_token_str      fluenci armenian russian english good communic...
# JobRequirment_token_str     assist cenn armenia countri coordin adminstr t...
# Name: 567, dtype: object
# SIMILARITY SCORE:  0.23618800488221392

# %% [markdown]
# ### Word and Doc Vectors

# %% [markdown]
# #### 1. Using online pretrained model
# https://spacy.io/models/en#en_core_web_lg

# %%
# to download model
#!python -m spacy download en_core_web_lg

nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# #### Note:
# Similarity is determined by comparing word vectors or "word embeddings", multi-dimensional meaning representations of a word. https://spacy.io/usage/spacy-101#vectors-similarity
#
# Similarity in Spacy is computed by:
#
#     return numpy.dot(self.vector, other.vector) / (self.vector_norm * other.vector_norm)
#
# This looks like its the formula for computing cosine similarity and the vectors seem to be created with SpaCy's .vector which documentation says is trained from GloVe's w2v model. https://spacy.io/api/token#similarity
#
# <u> From the spacy website: </u>
#
# Models that come with built-in word vectors make them available as the Token.vector  attribute. Doc.vector  and Span.vector  will default to an <b>average</b> of their token vectors.

# %% [markdown]
# #### Generate a final similarity score between two documents at a time, by comparing against,
# - Titles
# - Job Description
# - Job Requirements
# - Required Qualification

# %% [markdown]
# #### Note:
#
# The out of the box pretrained word embedding model gives decent results for Titles.
#
# But for other fields where the sentence vector is obtained by simply averaging word vectors alone, the pretrained word embedding model was not able to  distinguish well for RequiredQual, JobDescription and JobRequirment, regardless of the full string or using tokens after punctuation and stopwords removal.
#
# For most of the job comparisons, it gave high similarity score (>0.8)

# %%
# e.g. Original text - Title
doc1 = nlp(df_job_related.iloc[0]['Title'])
doc2 = nlp(df_job_related.iloc[2]['Title'])
similarity = doc1.similarity(doc2)
print("DOC1:\n" + doc1.text, "\n\nDOC2:\n", doc2.text, "\n\n", similarity)
# Out:
# DOC1:
# Chief Financial Officer
#
# DOC2:
#  Country Coordinator
#
#  0.537330015139695

# %%
# e.g. Original text - RequiredQual
doc1 = nlp(df_job_related.iloc[0]['RequiredQual'])
doc2 = nlp(df_job_related.iloc[2]['RequiredQual'])
similarity = doc1.similarity(doc2)
print("DOC1:\n" + doc1.text, "\n\nDOC2:\n", doc2.text, "\n\n", similarity)
# Out:
# DOC1:
# To perform this job successfully, an
# individual must be able to perform each essential duty satisfactorily.
# The requirements listed below are representative of the knowledge,
# skill, and/or ability required.
# Knowledge of:
# - Generally accepted accounting principles;
# - Local accounting standards and legislation;
# - State reporting requirements pertaining to accounting;
# - Principles and practices of financial management and budgeting;
# - Principles and practices of financial systems design and analysis;
# - Principles and practices of contract management, records management,
# and risk management;
# - Principles and practices of management and supervision;
# - Principles and practices of information systems management.
# Ability to:
# - Apply sound fiscal and administrative practices to the company's
# activities;
# - Plan, organize and supervise the work of subordinate employees,
# including training them, assigning and evaluating their work, and
# providing job performance feedback;
# - Critically analyze fiscal and administrative policies, practices,
# procedures, and systems, and recommend and implement changes as needed;
# - Gather and synthesize financial information from a variety of sources
# and present it to a variety of audiences with differing financial
# management and analysis expertise;
# - Prepare detailed, comprehensive financial reports, including
# explanatory text;
# - Operate IBM-compatible personal computer, including word processing,
# spreadsheet, and database software applications;
# - Operate specialized software applications that support the financial
# management and budgeting functions.
# Qualifications:
# - A minimum of 5-7 years Accounting/ Corporate Finance/ Banking
# experience, including a role as a CFO;
# - Excellent finance and accounting technical skills coupled with a
# demonstrated knowledge of all key financial functions in an consulting
# company context - accounting, finance, control, treasury, reserving, and
# reporting;
# - Strong financial planning and analytical skills and experience and the
# ability to work closely with and support the CEO and other executives in
# strategic development and implementation;
# - Excellent leadership, management and supervisory track record of
# attracting, selecting, developing, rewarding and retaining high-caliber,
# accounting and finance executive and teams who achieve business goals;
# - An undergraduate degree in finance, business, or other related
# discipline is required. A CPA, CFA, ACCA or other financial
# certification is highly preferred, as is a Masters degree in Business
# Administration, Accounting or Finance;
# - Fluency in English, Armenian and Russian with outstanding writing
# skills;
# - Excellent analytical, communication, teamwork, interpersonal skills;
# - Need to be well organized and detail-oriented as well as goal/ result
# driven and able to deal with complex issues.
#
# DOC2:
#  - Degree in environmentally related field, or 5 years relevant
# experience;
# - Oral and written fluency in Armenian, Russian and English;
# - Knowledge/ experience of working with environmental issues specific to
# Armenia is a plus.
# REMUNERATION:  Salary commensurate with experience.
#
#  0.9393333513526921

# %%
# E.g. removing stopwords and punctuations
doc1 = nlp(SPACE.join(df_job_related.iloc[0]['RequiredQual_token']))
doc2 = nlp(SPACE.join(df_job_related.iloc[2]['RequiredQual_token']))
similarity = doc1.similarity(doc2)
print("DOC1:\n" + doc1.text, "\n\nDOC2:\n", doc2.text, "\n\n", similarity)
# Out:
# DOC1:
# To perform job successfully individual must able perform essential duty satisfactorily The requirements listed representative knowledge skill and/or ability required Knowledge Generally accepted accounting principles Local accounting standards legislation State reporting requirements pertaining accounting Principles practices financial management budgeting Principles practices financial systems design analysis Principles practices contract management records management risk management Principles practices management supervision Principles practices information systems management Ability Apply sound fiscal administrative practices company's activities Plan organize supervise work subordinate employees including training assigning evaluating work providing job performance feedback Critically analyze fiscal administrative policies practices procedures systems recommend implement changes needed Gather synthesize financial information variety sources present variety audiences differing financial management analysis expertise Prepare detailed comprehensive financial reports including explanatory text Operate IBM-compatible personal computer including word processing spreadsheet database software applications Operate specialized software applications support financial management budgeting functions Qualifications A minimum 5-7 years Accounting/ Corporate Finance/ Banking experience including role CFO Excellent finance accounting technical skills coupled demonstrated knowledge key financial functions consulting company context accounting finance control treasury reserving reporting Strong financial planning analytical skills experience ability work closely support CEO executives strategic development implementation Excellent leadership management supervisory track record attracting selecting developing rewarding retaining high-caliber accounting finance executive teams achieve business goals An undergraduate degree finance business related discipline required A CPA CFA ACCA financial certification highly preferred Masters degree Business Administration Accounting Finance Fluency English Armenian Russian outstanding writing skills Excellent analytical communication teamwork interpersonal skills Need well organized detail-oriented well goal/ result driven able deal complex issues
#
# DOC2:
#  Degree environmentally related field 5 years relevant experience Oral written fluency Armenian Russian English Knowledge/ experience working environmental issues specific Armenia plus REMUNERATION Salary commensurate experience
#
#  0.8680116809882635

# %% [markdown]
# #### Extracting keywords using POS and Regex Matcher

# %%
from spacy.matcher import Matcher
from spacy import displacy

def collect_sents(matcher, doc, i, matches):
    match_id, start, end = matches[i]
    span = doc[start : end]  # matched span
    sent = span.sent  # sentence containing matched span
    # append mock entity for match in displaCy style to matched_sents
    # get the match span by ofsetting the start and end of the span with the
    # start and end of the sentence in the doc
    match_ents = [{'start': span.start_char - sent.start_char,
                   'end': span.end_char - sent.start_char,
                   'label': 'MATCH'}]
    matched_sents.append({'text': sent.text, 'ents': match_ents })

matcher = Matcher(nlp.vocab)
matched_sents = []

pattern = [{'POS':'ADJ'},{'ORTH': '-'}, {'POS':'NOUN', 'OP':'+'}, {'LOWER': 'organization'}]
matcher.add('company has', collect_sents, pattern)  # add pattern
pattern = [{'POS':'NOUN', 'OP':'+'}, {'LOWER': 'organization'}]
matcher.add('company has', collect_sents, pattern)  # add pattern
pattern = [{'POS':'NOUN', 'OP':'+'}, {'LOWER': 'company'}]
matcher.add('company has', collect_sents, pattern)  # add pattern
pattern = [{'POS':'NOUN', 'OP':'+'}, {'LOWER': 'services'}]
matcher.add('company has', collect_sents, pattern)  # add pattern
pattern = [{'LOWER': 'company'}, {'POS':'VERB'}, {'POS':'NOUN', 'OP':'+'}]
matcher.add('company has', collect_sents, pattern)  # add pattern
pattern = [{'LOWER':'provider'}, {'POS':'ADP'}, {'POS':'NOUN',  'OP': '+'}  , {'POS':'CCONJ','OP':'+'}, {'POS':'NOUN','OP':'+'}]
matcher.add('provider of', collect_sents, pattern)  # add pattern
pattern = [{'LOWER':'provider'}, {'POS':'ADP'}, {'POS':'NOUN',  'OP': '+'}]
matcher.add('provider of', collect_sents, pattern)  # add pattern
pattern = [{'POS':'VERB'}, {'POS':'NOUN',  'OP': '+'} ]
matcher.add('verb_noun', collect_sents, pattern)  # add pattern
pattern = [{'POS':'ADJ'}, {'POS':'NOUN',  'OP': '+'} ]
matcher.add('verb_noun', collect_sents, pattern)  # add pattern
pattern = [{'POS':'NOUN'}, {'POS':'ADP'}, {'POS':'NOUN',  'OP': '+'} ]
matcher.add('verb_noun', collect_sents, pattern)  # add pattern
pattern = [{'POS':'NOUN'}, {'POS':'NOUN','OP':'+'} ]
matcher.add('verb_noun', collect_sents, pattern)  # add pattern

# %%
SPACE = " "
for job1_idx in range(df_job_related.shape[0]):
    matched_sents = []
    keywords = []
    text = re.sub(r'\s+', ' ', df_job_related.iloc[job1_idx]['RequiredQual'])
    doc = nlp(text)
    matches = matcher(doc)
    for match_id, start, end in matches:
        string_id = nlp.vocab.strings[match_id]  # get string representation
        span = doc[start:end]  # the matched span
        keywords.append(span.text)
    df_job_related.set_value(job1_idx, 'RequiredQual_keywords', SPACE.join(keywords))

# %%
for job1_idx in range(df_job_related.shape[0]):
    matched_sents = []
    keywords = []
    text = re.sub(r'\s+', ' ', df_job_related.iloc[job1_idx]['JobDescription'])
    doc = nlp(text)
    matches = matcher(doc)
    for match_id, start, end in matches:
        string_id = nlp.vocab.strings[match_id]  # get string representation
        span = doc[start:end]  # the matched span
        keywords.append(span.text)
    df_job_related.set_value(job1_idx, 'JobDescription_keywords', SPACE.join(keywords))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-d5f3fcc85e91> in <module>()
#       2     matched_sents = []
#       3     keywords = []
# ----> 4     text = re.sub(r'\s+', ' ', df_job_related.iloc[job1_idx]['JobDescription'])
#       5     doc = nlp(text)
#       6     matches = matcher(doc)
#
# ~/anaconda3/lib/python3.6/re.py in sub(pattern, repl, string, count, flags)
#     189     a callable, it's passed the match object and must return
#     190     a replacement string to be used."""
# --> 191     return _compile(pattern, flags).sub(repl, string, count)
#     192
#     193 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
for job1_idx in range(df_job_related.shape[0]):
    matched_sents = []
    keywords = []
    text = re.sub(r'\s+', ' ', df_job_related.iloc[job1_idx]['JobRequirment'])
    doc = nlp(text)
    matches = matcher(doc)
    for match_id, start, end in matches:
        string_id = nlp.vocab.strings[match_id]  # get string representation
        span = doc[start:end]  # the matched span
        keywords.append(span.text)
    df_job_related.set_value(job1_idx, 'JobRequirment_keywords', SPACE.join(keywords))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-2fc85b0815d5> in <module>()
#       2     matched_sents = []
#       3     keywords = []
# ----> 4     text = re.sub(r'\s+', ' ', df_job_related.iloc[job1_idx]['JobRequirment'])
#       5     doc = nlp(text)
#       6     matches = matcher(doc)
#
# ~/anaconda3/lib/python3.6/re.py in sub(pattern, repl, string, count, flags)
#     189     a callable, it's passed the match object and must return
#     190     a replacement string to be used."""
# --> 191     return _compile(pattern, flags).sub(repl, string, count)
#     192
#     193 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# matched keywords highlighted - example for job 0
displacy.render(matched_sents, style='ent', manual=True, jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">To perform this job successfully, an individual must be able to perform each
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     essential duty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  satisfactorily.</div>
#
# <div class="entities" style="line-height: 2.5">Knowledge of: - Generally
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     accepted accounting principles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# ; - Local accounting standards and legislation; - State reporting requirements pertaining to accounting; - Principles and practices of financial management and budgeting; - Principles and practices of financial systems design and analysis; - Principles and practices of contract management, records management, and risk management; - Principles and practices of management and supervision; - Principles and practices of information systems management.</div>
#
# <div class="entities" style="line-height: 2.5">Knowledge of: - Generally
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     accepted accounting principles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# ; - Local accounting standards and legislation; - State reporting requirements pertaining to accounting; - Principles and practices of financial management and budgeting; - Principles and practices of financial systems design and analysis; - Principles and practices of contract management, records management, and risk management; - Principles and practices of management and supervision; - Principles and practices of information systems management.</div>
#
# <div class="entities" style="line-height: 2.5">Knowledge of: - Generally accepted
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     accounting principles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# ; - Local accounting standards and legislation; - State reporting requirements pertaining to accounting; - Principles and practices of financial management and budgeting; - Principles and practices of financial systems design and analysis; - Principles and practices of contract management, records management, and risk management; - Principles and practices of management and supervision; - Principles and practices of information systems management.</div>
#
# <div class="entities" style="line-height: 2.5">Knowledge of: - Generally accepted accounting principles; -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Local accounting standards
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  and legislation; - State reporting requirements pertaining to accounting; - Principles and practices of financial management and budgeting; - Principles and practices of financial systems design and analysis; - Principles and practices of contract management, records management, and risk management; - Principles and practices of management and supervision; - Principles and practices of information systems management.</div>
#
# <div class="entities" style="line-height: 2.5">Knowledge of: - Generally accepted accounting principles; -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Local accounting standards
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  and legislation; - State reporting requirements pertaining to accounting; - Principles and practices of financial management and budgeting; - Principles and practices of financial systems design and analysis; - Principles and practices of contract management, records management, and risk management; - Principles and practices of management and supervision; - Principles and practices of information systems management.</div>
#
# <div class="entities" style="line-height: 2.5">Knowledge of: - Generally accepted accounting principles; - Local
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     accounting standards
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  and legislation; - State reporting requirements pertaining to accounting; - Principles and practices of financial management and budgeting; - Principles and practices of financial systems design and analysis; - Principles and practices of contract management, records management, and risk management; - Principles and practices of management and supervision; - Principles and practices of information systems management.</div>
#
# <div class="entities" style="line-height: 2.5">Knowledge of: - Generally accepted accounting principles; - Local accounting standards and legislation; -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     State reporting requirements
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  pertaining to accounting; - Principles and practices of financial management and budgeting; - Principles and practices of financial systems design and analysis; - Principles and practices of contract management, records management, and risk management; - Principles and practices of management and supervision; - Principles and practices of information systems management.</div>
#
# <div class="entities" style="line-height: 2.5">Knowledge of: - Generally accepted accounting principles; - Local accounting standards and legislation; -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     State reporting requirements
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  pertaining to accounting; - Principles and practices of financial management and budgeting; - Principles and practices of financial systems design and analysis; - Principles and practices of contract management, records management, and risk management; - Pr

# %%
# keywords from the sentence - example for job 0
keywords
# Out:
# ['essential duty',
#  'accepted accounting principles',
#  'accepted accounting principles',
#  'accounting principles',
#  'Local accounting standards',
#  'Local accounting standards',
#  'accounting standards',
#  'State reporting requirements',
#  'State reporting requirements',
#  'reporting requirements',
#  'financial management',
#  'financial systems design',
#  'financial systems design',
#  'systems design',
#  'practices of contract management',
#  'practices of contract management',
#  'contract management',
#  'records management',
#  'risk management',
#  'practices of management',
#  'practices of information systems',
#  'practices of information systems management',
#  'information systems management',
#  'practices of information systems management',
#  'information systems management',
#  'systems management',
#  'administrative practices',
#  'subordinate employees',
#  'their work',
#  'providing job performance',
#  'providing job performance feedback',
#  'job performance feedback',
#  'providing job performance feedback',
#  'job performance feedback',
#  'performance feedback',
#  'administrative policies',
#  'implement changes',
#  'financial information',
#  'variety of sources',
#  'variety of audiences',
#  'financial management',
#  'analysis expertise',
#  'financial reports',
#  'explanatory text',
#  'personal computer',
#  'including word processing',
#  'including word processing',
#  'word processing',
#  'database software applications',
#  'database software applications',
#  'software applications',
#  'specialized software applications',
#  'specialized software applications',
#  'software applications',
#  'financial management',
#  'budgeting functions',
#  'Excellent finance',
#  'technical skills',
#  'demonstrated knowledge',
#  'financial functions',
#  'consulting company context',
#  'consulting company context',
#  'company context',
#  'financial planning',
#  'analytical skills',
#  'other executives',
#  'strategic development',
#  'Excellent leadership',
#  'supervisory track record',
#  'supervisory track record',
#  'track record',
#  'finance executive',
#  'teams who',
#  'achieve business goals',
#  'achieve business goals',
#  'business goals',
#  'undergraduate degree',
#  'degree in finance',
#  'related discipline',
#  'financial certification',
#  'outstanding writing skills',
#  'outstanding writing skills',
#  'writing skills',
#  'interpersonal skills',
#  'complex issues']

# %%
df_job_related.head(10)
# Out:
#                                                       Title  \
# 0                                   Chief Financial Officer
# 1  Full-time Community Connections Intern (paid internship)
# 2                                       Country Coordinator
# 3                                            BCC Specialist
# 4                                        Software Developer
# 5                                                Saleswoman
# 6                       Chief Accountant/ Finance Assistant
# 7            Non-paid part or full time Programmatic Intern
# 8                            Assistant to Managing Director
# 9                     Program Assistant (INL), FSN-8; FP-6*
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             JobDescription  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            AMERIA Investment Consulting Company is seeking a\nChief Financial Officer. This position manages the company's fiscal and\nadministrative functions, provides highly responsible and technically\ncomplex staff assistance to the Executive Director. The work performed\nrequires a high level of technical proficiency in financial management\nand investment management, as well as management, supervisory, and\nadministrative skills.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Public outreach and strengthening of a growing\nnetwork of environmental NGOs, businesses, international organizations\nand public agencies. Will serve as primary contact between CENN and\npublic. This is a full-time position.
# 3  The LEAD (Local Enhancement and Development for\nHealth) BCC Specialist will apply state-of-the-art approaches in working\nwith LGUs (Local Government Units) and NGOs to help them to identify and\naddress provider-caused barriers to service provision as well as to\nidentify and address supports for good service delivery by developing\ntools that may be adapted to each LGU's needs. S/he will work with LEAD\nstaff across all components to support quality service delivery and will\nalso monitor implementation of improved service delivery in LGUs, and\nwill provide additional assistance to LGUs and NGOs, as needed. S/he\nwill collect all relevant published and grey literature documents,\nidentify gaps in knowledge, and work with NGOs and consultants to fill\nin the gaps. S/he will establish training for NGOs and LGU\nadministration staff pursuing service enhancement and provider behavior\nchange and will oversee the training. S/he will serve as the Project's\nprimary liaison to TSAP an...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Saleswoman will sell menswear and accessories.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            The Armenian Branch Office of the Open Society\nInstitute Assistance Foundation is seeking applications for the position\nof Chief Accountant/ Finance Assistant. The Chief Accountant/ Finance\nAssistant will be responsible for all transactions, connected with grant\npayments, administrative expenses.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
# 9                                                                                                                                                                                                                                                                                                                                                The incumbent assists in coordinating INL-funded law\nenforcement and drug control programs in Armenia (including training\nprograms supported and implemented by US Agencies) to avoid duplication\nof effort with other programs and to ensure that assistance from various\nUSG agencies is complementary. Additionally, assists on coordinating US\nmission activities in the crime and narcotics area with other donors\nlike the United Nations, Non Governmental organizations and other\ninternational donors.\nA copy of the complete position description listing all duties and\nresponsibilities is available in the Human Resources Office. Contact\nnumber: (3741) 52-46-61
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               RequiredQual  \
# 0  To perform this job successfully, an\nindividual must be able to perform each essential duty satisfactorily.\nThe requirements listed below are representative of the knowledge,\nskill, and/or ability required.\nKnowledge of:\n- Generally accepted accounting principles;\n- Local accounting standards and legislation;\n- State reporting requirements pertaining to accounting;\n- Principles and practices of financial management and budgeting;\n- Principles and practices of financial systems design and analysis;\n- Principles and practices of contract management, records management,\nand risk management;\n- Principles and practices of management and supervision;\n- Principles and practices of information systems management.\nAbility to:\n- Apply sound fiscal and administrative practices to the company's\nactivities;\n- Plan, organize and supervise the work of subordinate employees,\nincluding training them, assigning and evaluating their work, and\nproviding job performance feedback;\n- ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   - Bachelor's Degree; Master's is preferred;\n- Excellent skills in spoken and written English and Armenian languages;\n- Past English to Armenian translation and Armenian to English\ntranslation experience;\n- Good communication and public speaking skills;\n- Ability to work independently and as part of a team.\nREMUNERATION:  Commensurate with experience.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             - Degree in environmentally related field, or 5 years relevant\nexperience;\n- Oral and written fluency in Armenian, Russian and English;\n- Knowledge/ experience of working with environmental issues specific to\nArmenia is a plus.\nREMUNERATION:  Salary commensurate with experience.
# 3                                                                                                                                                                                                                                                                                            - Advanced degree in public health, social science, or communication or\nrelated experience;\n- Familiarity with Behavior-centered Programming SM preferred;\n- At least five years experience in the design, implementation, and\nmonitoring/evaluation of behavior change programs in the developing\nworld, preferably including Philippines;\n- Experience with behavior change in reproductive health and/or family\nplanning programs;\n- Excellent communication, coordination, and facilitation skills;\n- Experience with PC-based software, including word processing and basic\nspreadsheet analysis;\n- Knowledge of a language of the Philippines, or willingness to learn;\n- High level of written and spoken English fluency.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               - University degree; economical background is a plus;\n- Excellent knowledge of Windows 2000 Server, Networking TCP/ IP\ntechnologies, MS SQL 2000 Server, Visual Basic 6;\n- At least 2 years of experience in database software development;\n- Good knowledge of English.\nREMUNERATION:  Will be commensurate with the norms accepted in the\nCompany.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   - Candidates should be female, 20-30 years old;\n- Nice-looking exterior; \n- Excellent communication skills;\n- Fluency in Armenian and Russian;  \n- Good knowledge of English (oral).\nREMUNERATION:  Starting salary - 40,000 AMD.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           - University degree in finance/ accounting; \n- One year minimum experience in an international organization; \n- Strong organizational skills; \n- Good knowledge of software programs: MS Excel and MS Access; \n- Good knowledge of IAS, Armenian taxation laws, reporting requirements\nand current reforms; \n- Discretion and ability to handle confidential issues; \n- Self-motivation with an ability to set and meet goals; \n- Quick learning skills; \n- Fluency in English, Armenian and Russian.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  - University degree;\n- At least 3 years of experience in the relevant field;\n- Mastership of the office work and competency of business ethics;\n- Excellent working knowledge of written and verbal Armenian, Russian\nand English; knowledge of French is a plus;\n- Knowledge of MS Office;\n- Strong problem-solving and organizational skills; outstanding\ninterpersonal skills.  \nREMUNERATION:  Will be commensurate with the norms accepted in the\nCompany
# 9  NOTE: All applicants are instructed to\naddress each selection criterion detailed below with specific and\ncomprehensive information supporting each criteria.\n- University degree in a relevant field (Law, Law Enforcement, Political\nScience, Public Administration) or its equivalent is required;\n- Two years of progressively responsible experience in program\nadministration and logistical support is required;\n- Level IV proficiency in English and Armenian;\n- Thorough knowledge of Armenian Criminal Justice System, legislative\nprocess, and structure and operations of law enforcement agencies\nrequired;\n- Sound management, analytical and organizational skills. \nSELECTION PROCESS:   When equally qualified, Eligible Family Members and\nU.S. Veterans will be given preference. Therefore, it is essential that\nall candidates address the required qualifications above in the\napplication. \nADDITIONAL SELECTION CRITERIA: \n1. Management will consider nepotism/ conflict of interest, budg...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              JobRequirment  \
# 0  - Supervises financial management and administrative staff, including\nassigning responsibilities, reviewing employees' work processes and\nproducts, counseling employees, giving performance evaluations, and\nrecommending disciplinary action;\n- Serves as member of management team participating in both strategic\nand operational planning for the company;\n- Directs and oversees the company's financial management activities,\nincluding establishing and monitoring internal controls, managing cash\nand investments, and managing the investment portfolio in collaboration\nwith the Investment team leader. This includes, but is not limited to,\nevaluation of investment risk, concentration risk, fund deployment\nlevels, adequacy of loss and liquidity reserves Assists investment team\nin development of proper documentation and internal systems;\n- Directs and oversees the annual budgeting process, including\ndeveloping projections for financial planning, and preparing budgets;\n- Prepares e...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            - Working with the Country Director to provide environmental information\nto the general public via regular electronic communications and serving\nas the primary local contact to Armenian NGOs and businesses and the\nArmenian offices of international organizations and agencies;\n- Helping to organize and prepare CENN seminars/ workshops;\n- Participating in defining the strategy and policy of CENN in Armenia,\nthe Caucasus region and abroad.
# 3  - Identify gaps in knowledge and overseeing information collection to\nfill them;\n- Consolidate partnerships with center of excellence of technical\nsupport, working with local NGOs/COs, LCEs, and LGUs;\n- Work with LEAD team to develop assessment tools for LGUs to identify\nbarriers and supports to quality service provision;\n- Assist LGUs and NGOs to design and implement multifaceted (if\nnecessary), systematic interventions, based on assessment results, to\nenhance quality service provision, especially through provider behavior\nchange. For example, ensure that not only providers, but their\nsupervisors are trained and that monitoring and supervisory systems\npromote provider change, quality services, and sustainability of change;\n- Assist other LEAD specialists and units to enhance the quality of\nservices, especially through BCC and provider behavior change, and\nassure that programs serve community needs;\n- Oversee and, when practical, co-facilitate behavior change trainin...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         - Rendering technical assistance to Database Management Systems;\n- Realization of SQL servers maintenance activities: back-up and\nreplication;\n- Participation in designing of software development projects.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        - Coordinating the work of subordinate employees;\n- Maintaining liaison with the other subdivisions within the Company;\n- Managing correspondence flow;\n- Realizing written and verbal translations;\n- Organizing meetings and conferences; compiling minutes of meetings;\n- Drawing reports;\n- Operating office equipment.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      nan
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           JobDescription_token  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [AMERIA, Investment, Consulting, Company, seeking, Chief, Financial, Officer, This, position, manages, company, 's, fiscal, administrative, functions, provides, highly, responsible, technically, complex, staff, assistance, Executive, Director, The, work, performed, requires, high, level, technical, proficiency, financial, management, investment, management, well, management, supervisory, administrative, skills]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [nan]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [Public, outreach, strengthening, growing, network, environmental, NGOs, businesses, international, organizations, public, agencies, Will, serve, primary, contact, CENN, public, This, full-time, position]
# 3  [The, LEAD, Local, Enhancement, Development, Health, BCC, Specialist, apply, state-of-the-art, approaches, working, LGUs, Local, Government, Units, NGOs, help, identify, address, provider-caused, barriers, service, provision, well, identify, address, supports, good, service, delivery, developing, tools, may, adapted, LGU, 's, needs, S/he, work, LEAD, staff, across, components, support, quality, service, delivery, also, monitor, implementation, improved, service, delivery, LGUs, provide, additional, assistance, LGUs, NGOs, needed, S/he, collect, relevant, published, grey, literature, documents, identify, gaps, knowledge, work, NGOs, consultants, fill, gaps, S/he, establish, training, NGOs, LGU, administration, staff, pursuing, service, enhancement, provider, behavior, change, oversee, training, S/he, serve, Project's, primary, liaison, TSAP, projects, organizations, working, ...]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [nan]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [Saleswoman, sell, menswear, accessories]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [The, Armenian, Branch, Office, Open, Society, Institute, Assistance, Foundation, seeking, applications, position, Chief, Accountant/, Finance, Assistant, The, Chief, Accountant/, Finance, Assistant, responsible, transactions, connected, grant, payments, administrative, expenses]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [nan]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [nan]
# 9                                                                                                                                                                                                                                                                                                               [The, incumbent, assists, coordinating, INL-funded, law, enforcement, drug, control, programs, Armenia, including, training, programs, supported, implemented, US, Agencies, avoid, duplication, effort, programs, ensure, assistance, various, USG, agencies, complementary, Additionally, assists, coordinating, US, mission, activities, crime, narcotics, area, donors, like, United, Nations, Non, Governmental, organizations, international, donors, A, copy, complete, position, description, listing, duties, responsibilities, available, Human, Resources, Office, Contact, number, 3741, 52-46-61]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         RequiredQual_token  \
# 0  [To, perform, job, successfully, individual, must, able, perform, essential, duty, satisfactorily, The, requirements, listed, representative, knowledge, skill, and/or, ability, required, Knowledge, Generally, accepted, accounting, principles, Local, accounting, standards, legislation, State, reporting, requirements, pertaining, accounting, Principles, practices, financial, management, budgeting, Principles, practices, financial, systems, design, analysis, Principles, practices, contract, management, records, management, risk, management, Principles, practices, management, supervision, Principles, practices, information, systems, management, Ability, Apply, sound, fiscal, administrative, practices, company's, activities, Plan, organize, supervise, work, subordinate, employees, including, training, assigning, evaluating, work, providing, job, performance, feedback, Critically, analyze, fiscal, administrative, policies, practices, procedures, systems, recommend, implement, changes, ne...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [Bachelor, 's, Degree, Master, 's, preferred, Excellent, skills, spoken, written, English, Armenian, languages, Past, English, Armenian, translation, Armenian, English, translation, experience, Good, communication, public, speaking, skills, Ability, work, independently, part, team, REMUNERATION, Commensurate, experience]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [Degree, environmentally, related, field, 5, years, relevant, experience, Oral, written, fluency, Armenian, Russian, English, Knowledge/, experience, working, environmental, issues, specific, Armenia, plus, REMUNERATION, Salary, commensurate, experience]
# ...
# 4
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           sell menswear
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             seeking applications grant payments administrative expenses
# 7
# 8
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                             coordinating INL funded law enforcement funded law enforcement law enforcement drug control programs drug control programs control programs including training programs including training programs training programs avoid duplication duplication of effort other programs mission activities narcotics area other donors Governmental organizations international donors complete position description complete position description position description Contact number
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     JobRequirment_keywords
# 0  financial management administrative staff assigning responsibilities reviewing employees work processes counseling employees giving performance evaluations giving performance evaluations performance evaluations disciplinary action member of management team member of management team management team operational planning financial management activities financial management activities management activities internal controls managing cash investment portfolio portfolio in collaboration team leader evaluation of investment risk evaluation of investment risk investment risk concentration risk fund deployment levels fund deployment levels deployment levels adequacy of loss liquidity reserves investment team team in development proper documentation internal systems annual budgeting process annual budgeting process budgeting process developing projections financial planning preparing budgets financial management reports financial management reports management reports financial statements tax...
# 1
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            environmental information general public electronic communications local contact Armenian offices international organizations
# 3  Identify gaps gaps in knowledge overseeing information collection overseeing information collection information collection Consolidate partnerships partnerships with center center of excellence technical support LEAD team develop assessment tools develop assessment tools assessment tools tools for LGUs identify barriers supports to quality service supports to quality service provision quality service provision supports to quality service provision quality service provision service provision Assist LGUs systematic interventions assessment results enhance quality service enhance quality service provision quality service provision enhance quality service provision quality service provision service provision provider behavior change provider behavior change behavior change only providers their supervisors supervisory systems promote provider change promote provider change provider change quality services quality services sustainability of change quality of services provider behavior ch...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            technical assistance servers maintenance activities servers maintenance activities maintenance activities Participation in designing designing of software development designing of software development projects software development projects designing of software development projects software development projects development projects
# 5
# 6
# 7
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          subordinate employees Maintaining liaison other subdivisions Managing correspondence flow Managing correspondence flow correspondence flow verbal translations Organizing meetings compiling minutes minutes of meetings Drawing reports Operating office equipment Operating office equipment office equipment
# 9

# %%
# optional - saving df to disk for future
df_job_related.to_csv("job_similarity_df_with_keywords.csv", index=False, sep='\t')

# %% [markdown]
# #### Create a job-similarity matrix storing the values of similarity(cosine) scores between two jobs
#
# ##### Note:
# Computing 1 vs 19K jobs takes 1 hour.
#
# Computing entire matrix will not be feasible.
#
# Hence only 3 jobs were selected for this operation and restricted to first 1000 jobs.

# %%
# iterate through each row vs rest of rows to calculate DIS-similarity

job_dissimilarity_df = pd.DataFrame(columns=['index', 'similar-job', 'dissimilar-score'])

for job1_idx in range(3):  # rows
    for job2_idx in range(1000):

        doc1 = nlp(df_job_related.iloc[job1_idx]['Title'])
        doc2 = nlp(df_job_related.iloc[job2_idx]['Title'])
        title_similarity = doc1.similarity(doc2)
        
        doc1 = nlp(df_job_related.iloc[job1_idx]['JobDescription_keywords'])
        doc2 = nlp(df_job_related.iloc[job2_idx]['JobDescription_keywords'])
        jd_similarity = doc1.similarity(doc2)
        
        doc1 = nlp(df_job_related.iloc[job1_idx]['JobRequirment_keywords'])
        doc2 = nlp(df_job_related.iloc[job2_idx]['JobRequirment_keywords'])
        jr_similarity = doc1.similarity(doc2)
        
        doc1 = nlp(df_job_related.iloc[job1_idx]['RequiredQual_keywords'])
        doc2 = nlp(df_job_related.iloc[job2_idx]['RequiredQual_keywords'])
        rq_similarity = doc1.similarity(doc2)
        
        averaged_score = (title_similarity + jd_similarity + jr_similarity + rq_similarity) / 4.0
        job_dissimilarity_df = job_dissimilarity_df.append({'index': job1_idx, 'similar-job': job2_idx, 'dissimilar-score': (1-averaged_score)},ignore_index=True)

# %%
job_dissimilarity_df.head(10)
# Out:
#    index  similar-job  dissimilar-score
# 0    0.0          0.0          0.000000
# 1    0.0          1.0          0.691006
# 2    0.0          2.0          0.248817
# 3    0.0          3.0          0.275137
# 4    0.0          4.0          0.481422
# 5    0.0          5.0          0.708744
# 6    0.0          6.0          0.358109
# 7    0.0          7.0          0.874434
# 8    0.0          8.0          0.379402
# 9    0.0          9.0          0.468607

# %% [markdown]
# ### Show top similar jobs

# %%
job_dissimilarity_df_sorted = job_dissimilarity_df.sort_values(by=['index', 'dissimilar-score'], ascending=[True, True])

# %%
job_dissimilarity_df_sorted.head(10)
# Out:
#      index  similar-job  dissimilar-score
# 0      0.0          0.0          0.000000
# 859    0.0        859.0          0.109565
# 446    0.0        446.0          0.117994
# 776    0.0        776.0          0.126975
# 72     0.0         72.0          0.135553
# 581    0.0        581.0          0.142030
# 970    0.0        970.0          0.142128
# 925    0.0        925.0          0.149169
# 153    0.0        153.0          0.151827
# 862    0.0        862.0          0.152852

# %%
# Show top 5 similar results to job - Chief Financial Officer
similar_jobs = job_dissimilarity_df_sorted.loc[job_dissimilarity_df_sorted['index'] == 0].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)].replace(r'\n',' ', regex=True))
# Out:
# Title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Chief Financial Officer
# JobDescription                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             AMERIA Investment Consulting Company is seeking a Chief Financial Officer. This position manages the company's fiscal and administrative functions, provides highly responsible and technically complex staff assistance to the Executive Director. The work performed requires a high level of technical proficiency in financial management and investment management, as well as management, supervisory, and administrative skills.
# RequiredQual               To perform this job successfully, an individual must be able to perform each essential duty satisfactorily. The requirements listed below are representative of the knowledge, skill, and/or ability required. Knowledge of: - Generally accepted accounting principles; - Local accounting standards and legislation; - State reporting requirements pertaining to accounting; - Principles and practices of financial management and budgeting; - Principles and practices of financial systems design and analysis; - Principles and practices of contract management, records management, and risk management; - Principles and practices of management and supervision; - Principles and practices of information systems management. Ability to: - Apply sound fiscal and administrative practices to the company's activities; - Plan, organize and supervise the work of subordinate employees, including training them, assigning and evaluating their work, and providing job performance feedback; - Critically analyze f...
# JobRequirment              - Supervises financial management and administrative staff, including assigning responsibilities, reviewing employees' work processes and products, counseling employees, giving performance evaluations, and recommending disciplinary action; - Serves as member of management team participating in both strategic and operational planning for the company; - Directs and oversees the company's financial management activities, including establishing and monitoring internal controls, managing cash and investments, and managing the investment portfolio in collaboration with the Investment team leader. This includes, but is not limited to, evaluation of investment risk, concentration risk, fund deployment levels, adequacy of loss and liquidity reserves Assists investment team in development of proper documentation and internal systems; - Directs and oversees the annual budgeting process, including developing projections for financial planning, and preparing budgets; - Prepares external and int...
# JobDescription_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [AMERIA, Investment, Consulting, Company, seeking, Chief, Financial, Officer, This, position, manages, company, 's, fiscal, administrative, functions, provides, highly, responsible, technically, complex, staff, assistance, Executive, Director, The, work, performed, requires, high, level, technical, proficiency, financial, management, investment, management, well, management, supervisory, administrative, skills]
# RequiredQual_token         [To, perform, job, successfully, individual, must, able, perform, essential, duty, satisfactorily, The, requirements, listed, representative, knowledge, skill, and/or, ability, required, Knowledge, Generally, accepted, accounting, principles, Local, accounting, standards, legislation, State, reporting, requirements, pertaining, accounting, Principles, practices, financial, management, budgeting, Principles, practices, financial, systems, design, analysis, Principles, practices, contract, management, records, management, risk, management, Principles, practices, management, supervision, Principles, practices, information, systems, management, Ability, Apply, sound, fiscal, administrative, practices, company's, activities, Plan, organize, supervise, work, subordinate, employees, including, training, assigning, evaluating, work, providing, job, performance, feedback, Critically, analyze, fiscal, administrative, policies, practices, procedures, systems, recommend, implement, changes, ne...
# JobRequirment_token        [Supervises, financial, management, administrative, staff, including, assigning, responsibilities, reviewing, employees, work, processes, products, counseling, employees, giving, performance, evaluations, recommending, disciplinary, action, Serves, member, management, team, participating, strategic, operational, planning, company, Directs, oversees, company, 's, financial, management, activities, including, establishing, monitoring, internal, controls, managing, cash, investments, managing, investment, portfolio, collaboration, Investment, team, leader, This, includes, limited, evaluation, investment, risk, concentration, risk, fund, deployment, levels, adequacy, loss, liquidity, reserves, Assists, investment, team, development, proper, documentation, internal, systems, Directs, oversees, annual, budgeting, process, including, developing, projections, financial, planning, preparing, budgets, Prepares, external, internal, financial, management, reports, audited, financial, statement...
# RequiredQual_keywords      essential duty accepted accounting principles accepted accounting principles accounting principles Local accounting standards Local accounting standards accounting standards State reporting requirements State reporting requirements reporting requirements financial management financial systems design financial systems design systems design practices of contract management practices of contract management contract management records management risk management practices of management practices of information systems practices of information systems management information systems management practices of information systems management information systems management systems management administrative practices subordinate employees their work providing job performance providing job performance feedback job performance feedback providing job performance feedback job performance feedback performance feedback administrative policies implement changes financial information variety of sources ...
# JobDescription_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              administrative functions complex staff assistance complex staff assistance staff assistance high level technical proficiency financial management investment management administrative skills
# JobRequirment_keywords     financial management administrative staff assigning responsibilities reviewing employees work processes counseling employees giving performance evaluations giving performance evaluations performance evaluations disciplinary action member of management team member of management team management team operational planning financial management activities financial management activities management activities internal controls managing cash investment portfolio portfolio in collaboration team leader evaluation of investment risk evaluation of investment risk investment risk concentration risk fund deployment levels fund deployment levels deployment levels adequacy of loss liquidity reserves investment team team in development proper documentation internal systems annual budgeting process annual budgeting process budgeting process developing projections financial planning preparing budgets financial management reports financial management reports management reports financial statements tax...
# Name: 0, dtype: object
# Title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Chief Accountant
# JobDescription                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Chief Accountant will be supervised by Financial Director of the Company.
# RequiredQual                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    - University degree in Accounting/ Finance; - Russian and Armenian language proficiency, knowledge of English language is desired; - Excellent computer skills, including Excel, knowledge of financial databases and accounting softwares; - 4 years of prior experience as a Chief Accountant or in equivalent finance position.
# JobRequirment                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   - Preparate monthly and annual financial and tax reports; - Tax management of projects; - Wire transfer maintenance; - Supervise financial aspects of Ameria CJSC.
# JobDescription_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [Chief, Accountant, supervised, Financial, Director, Company]
# RequiredQual_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [University, degree, Accounting/, Finance, Russian, Armenian, language, proficiency, knowledge, English, language, desired, Excellent, computer, skills, including, Excel, knowledge, financial, databases, accounting, softwares, 4, years, prior, experience, Chief, Accountant, equivalent, finance, position]
# JobRequirment_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [Preparate, monthly, annual, financial, tax, reports, Tax, management, projects, Wire, transfer, maintenance, Supervise, financial, aspects, Ameria, CJSC]
# RequiredQual_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          writing skills English languages Good working knowledge Good working knowledge working knowledge knowledge of computer applications knowledge of computer applications computer applications spreadsheet software packages spreadsheet software packages software packages Progressive work experience Progressive work experience work experience similar position
# JobDescription_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Management Consultant multiple projects projects under supervision ongoing support junior staff staff through project activities staff through project activities project activities development activities general business development general business development business development other responsibilities successful implementation
# JobRequirment_keywords     Elaborate business plans Elaborate business plans business plans feasibility studies due diligence assignments due diligence assignments diligence assignments Elaborate enterprise restructuring Elaborate enterprise restructuring enterprise restructuring rehabilitation projects Prepare investment memorandums Prepare investment memorandums investment memorandums Structure debt equity financing projects equity financing projects financing projects Prepare investment application Prepare investment application packages investment application packages Prepare investment application packages investment application packages application packages Conduct market researches Conduct market researches market researches Conduct sector surveys Conduct sector surveys sector surveys Conduct industry analyses Conduct industry analyses industry analyses various project management various project management assignments project management assignments various project management assignments project manage...
# Name: 860, dtype: object
# Title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Chief Accountant
# JobDescription                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Rasco-Armenia cjsc is looking to recruit a highly professional Chief Accountant for a newly established insurance company. This position will carry out routine accounting and financial reporting of the company.
# RequiredQual                                                                                                                                       - University degree in Economics / Finance / Accounting; - professional qualification certificate issued by the Ministry of Finance of the Republic of Armenia;  - ACCA degree is desirable; - experience at the Armenian insurance market highly desirable; - at least 2-year experience as a Chief Accountant; - excellent knowledge of Generally Accepted Accounting Principles, International and Armenian   Accounting Standards; - working knowledge of insurance market theory and practice;  - excellent knowledge of Armenian and Russian, knowledge of a foreign language is desirable;  - Computer literacy and knowledge of office applications, knowledge of accounting software; - Analytical skills and attention to detail; - Honesty and dedication.
# JobRequirment                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        nan
# JobDescription_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [Rasco-Armenia, cjsc, looking, recruit, highly, professional, Chief, Accountant, newly, established, insurance, company, This, position, carry, routine, accounting, financial, reporting, company]
# RequiredQual_token                                                                                                                                                                                                       [University, degree, Economics, Finance, Accounting, professional, qualification, certificate, issued, Ministry, Finance, Republic, Armenia, ACCA, degree, desirable, experience, Armenian, insurance, market, highly, desirable, least, 2-year, experience, Chief, Accountant, excellent, knowledge, Generally, Accepted, Accounting, Principles, International, Armenian, Accounting, Standards, working, knowledge, insurance, market, theory, practice, excellent, knowledge, Armenian, Russian, knowledge, foreign, language, desirable, Computer, literacy, knowledge, office, applications, knowledge, accounting, software, Analytical, skills, attention, detail, Honesty, dedication]
# JobRequirment_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [nan]
# RequiredQual_keywords                                                                                                                                                                                                            public health international organizations government officials medical community Medical qualification recognized university Competency in data collection Competency in data collection data collection quantitative research approaches quantitative research approaches research approaches excellent report writing excellent report writing skills report writing skills excellent report writing skills report writing skills writing skills utilizing spreadsheets database programs word processing systems word processing systems processing systems writing skills working time working hours Excellent interpersonal communication skills successful applicant show honesty
# JobDescription_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               direct coordination technical monitoring care project success care project success project success
# JobRequirment_keywords     National office extensive countrywide travel extensive countrywide travel countrywide travel related guides new training materials new training materials training materials overall program effectiveness overall program effectiveness program effectiveness implementation of program activities implementation of program activities program activities assigned sites technical monitoring technical reports field staff local partners field local partners field staff partners field staff local partners field staff partners field staff field staff target beneficiaries program implementation facilitation of data collection facilitation of data collection data collection Fostering working relationship Fostering working relationship working relationship national health authorities national health authorities health authorities medical community other counterparts
# Name: 447, dtype: object
# Title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Chief Engineer
# JobDescription             The Chief Engineer will be responsible for all engineering and technical outputs in a five-year public works program (PWP) financed by USAID. The public works programs will provide vocational training and immediate income to those who are unemployed, while at the same time meeting high priority community infrastructure needs. The position will be based in Yerevan, but will require frequent travel to regions. The Chief Engineer will manage a staff of five, employing construction workers, supervising design preparation, and managing construction works. The project will implement eight infrastructure rehabilitation projects per year in the regions of Armenia, such as water systems, health posts, schools. The Chief Engineer will be responsible to the Project Director. The position is effective upon the award of a contract by USAID.
# RequiredQual                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 - Five years experience in engineering in development programs in Armenia; - Strong understanding of designs (assessment of design will be part of interview process); - Experience in previous Public Works Programs in Armenia preferred; - Strong knowledge of Microsoft Excel and Word; - Problem solving capabilities; - Excellent organizational skills, ability to handle multiple priorities.
# JobRequirment                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        - Management of technical staff; - Responsible for ensuring that all eight projects are completed with quality and on time; - Ensure that designs meet IRD standards; - Work with procurement staff to ensure that the bidding incorporates all required norms and standards.
# JobDescription_token                                                                                                      [The, Chief, Engineer, responsible, engineering, technical, outputs, five-year, public, works, program, PWP, financed, USAID, The, public, works, programs, provide, vocational, training, immediate, income, unemployed, time, meeting, high, priority, community, infrastructure, needs, The, position, based, Yerevan, require, frequent, travel, regions, The, Chief, Engineer, manage, staff, five, employing, construction, workers, supervising, design, preparation, managing, construction, works, The, project, implement, eight, infrastructure, rehabilitation, projects, per, year, regions, Armenia, water, systems, health, posts, schools, The, Chief, Engineer, responsible, Project, Director, The, position, effective, upon, award, contract, USAID]
# RequiredQual_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [Five, years, experience, engineering, development, programs, Armenia, Strong, understanding, designs, assessment, design, part, interview, process, Experience, previous, Public, Works, Programs, Armenia, preferred, Strong, knowledge, Microsoft, Excel, Word, Problem, solving, capabilities, Excellent, organizational, skills, ability, handle, multiple, priorities]
# JobRequirment_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [Management, technical, staff, Responsible, ensuring, eight, projects, completed, quality, time, Ensure, designs, meet, IRD, standards, Work, procurement, staff, ensure, bidding, incorporates, required, norms, standards]
# RequiredQual_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               years experience managing finance administrative activities activities for development programs activities for development programs development programs extended period period of time financial regulations Strong knowledge High degree degree of integrity
# JobDescription_keywords                                                                                                                                                                                                           administrative activities public works program public works program works program works programs vocational training immediate income same time high priority community high priority community infrastructure priority community infrastructure high priority community infrastructure needs priority community infrastructure needs community infrastructure needs high priority community infrastructure needs priority community infrastructure needs community infrastructure needs infrastructure needs infrastructure rehabilitation projects infrastructure rehabilitation projects rehabilitation projects projects per year water systems health posts
# JobRequirment_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 financial management expenditure control project accountability cash flow financial control environment financial control environment control environment implementation of finance administrative procedures support staff
# Name: 777, dtype: object
# Title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Director of Finance and Accounting
# JobDescription                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Excellent knowledge of Accounting/Tax filing both Central Bank and Tax Dept., budget formation, presentation and control.
# RequiredQual                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        at least 3-4 years experience in audit/bank/lending REMUNERATION:   negotiable
# JobRequirment                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  nan
# JobDescription_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [Excellent, knowledge, Accounting/Tax, filing, Central, Bank, Tax, Dept., budget, formation, presentation, control]
# RequiredQual_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [least, 3-4, years, experience, audit/bank/lending, REMUNERATION, negotiable]
# JobRequirment_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [nan]
# RequiredQual_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  oral fluency Advanced computer skills Advanced computer skills computer skills Essential knowledge years of experience related field local organizations Demonstrated ability maintain confidentiality team member organizational skills attention to details above statements general nature level of work exhaustive list
# JobDescription_keywords                                                                                                                                                                                                                                                                                                                                                           national staff position national staff position staff position head office financial operations head office field offices double entry bookkeeping double entry bookkeeping entry bookkeeping accrual bases bases in compliance Accounting software double entry bookkeeping double entry bookkeeping entry bookkeeping effective accounting internal controls fund control policies fund control policies control policies Effective preparation financial records financial operations effective communication coordination with management field offices effective business relations effective business relations business relations outside auditors regulatory authorities
# JobRequirment_keywords     Manage program financial system Implement general organization in accordance donor organizations complete accounting internal control systems internal control systems control systems relevant records Review expenditures Initiate payment vouchers Initiate payment vouchers payment vouchers invoices for accuracy bank accounts keep track track of balances ensure sufficiency sufficiency of funds Input data financial databases double entry system double entry system entry system monthly accounts financial reports other tracking reports other tracking reports tracking reports car usage Perform reconciliations bank reconciliation petty cash reconciliation petty cash reconciliation cash reconciliation fuel coupon reconciliation fuel coupon reconciliation coupon reconciliation various ledgers ledgers for control purposes ledgers for control purposes control purposes Purchase Order Register Purchase Order Register Order Register Manage expenditures external auditors tax authorities government...
# Name: 73, dtype: object
# Title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Chief of Party
# JobDescription                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Development Alternatives Inc. is seeking long-term Chief of  Party candidates in the field of public policy/ policy advocacy to provide overall strategic direction and policy guidance for DAI's Peru Alternative  Development Project, a USAID funded project designed to support the  strengthening of policies to improve the implementation, effectiveness, and sustainability of social and economic activities related to Peru's National Alternative Development program.
# RequiredQual                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 - Three to five years of COP experience preferably in Latin America;  - Prior experience working in Peru;  - Strong technical knowledge of public advocacy, public policy, policy reform, or alternative development;  - Knowledge/understanding of alternative development efforts in Peru or Latin America;  - Knowledge of USAID rules and regulations and prior experience working on a USAID-funded project;  - Advanced degree in a related field;  - Spanish language fluency.
# JobRequirment              - Lead DAI consultants in carrying out their work.  - Promote policy changes in Peru by exercising public advocacy expertise. - Draft and/or provide substantive comments on SOWs. - Serve as a lead voice with the GOP and other organizations on this program.  - Provide  overall intellectual vision and strategic direction to the project.  - Provide policy guidance to project staff, consultants, and subcontractors.  - Work closely with the USAID Mission to develop and/or adhere to a work plan while being flexible in order to respond to potentially rapidly changing events and expectations.  - Ensure that deadlines set forth in the project work plan are met and that deliverables are of high quality. - Oversee monitoring and evaluation of results. - Ensure the timely completion of key activities. - Provide overall project management and serve as primary liaison between the project, GOP, USAID, and DAI.  - Supervise and coordinate the work of all long and short-term staff and subcontractor...
# JobDescription_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [Development, Alternatives, Inc., seeking, long-term, Chief, Party, candidates, field, public, policy/, policy, advocacy, provide, overall, strategic, direction, policy, guidance, DAI, 's, Peru, Alternative, Development, Project, USAID, funded, project, designed, support, strengthening, policies, improve, implementation, effectiveness, sustainability, social, economic, activities, related, Peru, 's, National, Alternative, Development, program]
# RequiredQual_token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [Three, five, years, COP, experience, preferably, Latin, America, Prior, experience, working, Peru, Strong, technical, knowledge, public, advocacy, public, policy, policy, reform, alternative, development, Knowledge/understanding, alternative, development, efforts, Peru, Latin, America, Knowledge, USAID, rules, regulations, prior, experience, working, USAID-funded, project, Advanced, degree, related, field, Spanish, language, fluency]
# JobRequirment_token                                                                                                             [Lead, DAI, consultants, carrying, work, Promote, policy, changes, Peru, exercising, public, advocacy, expertise, Draft, and/or, provide, substantive, comments, SOWs, Serve, lead, voice, GOP, organizations, program, Provide, overall, intellectual, vision, strategic, direction, project, Provide, policy, guidance, project, staff, consultants, subcontractors, Work, closely, USAID, Mission, develop, and/or, adhere, work, plan, flexible, order, respond, potentially, rapidly, changing, events, expectations, Ensure, deadlines, set, forth, project, work, plan, met, deliverables, high, quality, Oversee, monitoring, evaluation, results, Ensure, timely, completion, key, activities, Provide, overall, project, management, serve, primary, liaison, project, GOP, USAID, DAI, Supervise, coordinate, work, long, short-term, staff, subcontractors, Determine, STTA, requirements, timing, level, effort, ...]
# RequiredQual_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             advanced degree years experience experience in accountancy year experience international organization Advanced knowledge international accounting taxation principles accounting policies financial knowledge analysis skills good knowledge financial databases
# JobDescription_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  professional finance management professional finance management service finance management service professional finance management service finance management service management service daily accounting
# JobRequirment_keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Budget planning related documentation maintenance related documentation maintenance documentation maintenance financial reports local tax authorities local tax authorities tax authorities including payments bank checks financial reports budget expenses planned ones
# Name: 582, dtype: object

# %%
# Show top 5 similar results to job - Country Coordinator
similar_jobs = job_dissimilarity_df_sorted.loc[job_dissimilarity_df_sorted['index'] == 2].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                                                    Country Coordinator
# JobDescription             Public outreach and strengthening of a growing...
# RequiredQual               - Degree in environmentally related field, or ...
# JobRequirment              - Working with the Country Director to provide...
# JobDescription_token       [Public, outreach, strengthening, growing, net...
# RequiredQual_token         [Degree, environmentally, related, field, 5, y...
# JobRequirment_token        [Working, Country, Director, provide, environm...
# RequiredQual_keywords      related field relevant experience written flue...
# JobDescription_keywords    Public outreach growing network international ...
# JobRequirment_keywords     environmental information general public elect...
# Name: 2, dtype: object
# Title                                                Agriculture Coordinator
# JobDescription             Facilitating diversified and market oriented a...
# RequiredQual               -\tUniversity degree in Agriculture is require...
# JobRequirment              -\tEstablish demonstration plots in selected m...
# JobDescription_token       [Facilitating, diversified, market, oriented, ...
# RequiredQual_token         [University, degree, Agriculture, required, Pr...
# JobRequirment_token        [Establish, demonstration, plots, selected, mi...
# RequiredQual_keywords      Strong leadership organizational skills Proven...
# JobDescription_keywords    strategic issues issues for community developm...
# JobRequirment_keywords     support community development support communit...
# Name: 488, dtype: object
# Title                                                    Program Coordinator
# JobDescription             REPORTS TO: Chief of Party \nSUPERVISES: Infor...
# RequiredQual               Sufficient education, training and/or work exp...
# JobRequirment              Essential and other important responsibilities...
# JobDescription_token       [REPORTS, TO, Chief, Party, SUPERVISES, Inform...
# RequiredQual_token         [Sufficient, education, training, and/or, work...
# JobRequirment_token        [Essential, important, responsibilities, dutie...
# RequiredQual_keywords      following knowledge formal schooling prior exp...
# JobDescription_keywords    close collaboration effective implementation t...
# JobRequirment_keywords     relevant support teams relevant support teams ...
# Name: 356, dtype: object
# Title                                                    Project Coordinator
# JobDescription             The candidate should be a dynamic personality,...
# RequiredQual               - Highly motivated professionals, MD, possibly...
# JobRequirment              - Policy and guidelines development;\n- Organi...
# JobDescription_token       [The, candidate, dynamic, personality, excepti...
# RequiredQual_token         [Highly, motivated, professionals, MD, possibl...
# JobRequirment_token        [Policy, guidelines, development, Organization...
# RequiredQual_keywords      Relevant post graduate Relevant post graduate ...
# JobDescription_keywords    appropriate candidate exact title daily operat...
# JobRequirment_keywords     informal relationship primary liaison liaison ...
# Name: 734, dtype: object
# Title                                               Administrative Assistant
# JobDescription             This is an excellent opportunity for the right...
# RequiredQual               - Fluency in spoken and written English; knowl...
# JobRequirment              - Responsible for managing office administrati...
# JobDescription_token       [This, excellent, opportunity, right, person, ...
# RequiredQual_token         [Fluency, spoken, written, English, knowledge,...
# JobRequirment_token        [Responsible, managing, office, administration...
# RequiredQual_keywords      European languages administrative skills knowl...
# JobDescription_keywords    excellent opportunity right person charitable ...
# JobRequirment_keywords     managing office administration managing office...
# Name: 20, dtype: object
# Title                                                     Health Coordinator
# JobDescription             Health Coordinator will be responsible for dir...
# RequiredQual               -\tExperience of working in the field of publi...
# JobRequirment              The position is starting in August 2004 and is...
# JobDescription_token       [Health, Coordinator, responsible, direct, coo...
# RequiredQual_token         [Experience, working, field, public, health, w...
# JobRequirment_token        [The, position, starting, August, 2004, based,...
# RequiredQual_keywords      following knowledge formal schooling prior exp...
# JobDescription_keywords    implementing partners providing support progra...
# JobRequirment_keywords     other documents project duration develop progr...
# Name: 448, dtype: object

# %% [markdown]
# ### 2. Using custom Doc2Vec
# #### Note:
# This has already been done, so just going to load the model and compute similarity

# %%
from gensim.models.doc2vec import Doc2Vec

filename = "../classification/models/doc2vec_model_trained_300"
d2vmodel = Doc2Vec.load(filename)

# %% [markdown]
# #### Keeping original columns

# %%
# iterate through each row vs rest of rows to calculate DIS-similarity

job_dissimilarity_d2v_df = pd.DataFrame(columns=['index', 'similar-job', 'dissimilar-score'])

for job1_idx in range(3):  # rows
    for job2_idx in range(1000):
        title_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['Title'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['Title'].split()))
        jd_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['JobDescription'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['JobDescription'].split()))
        jr_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['JobRequirment'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['JobRequirment'].split()))
        rq_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['RequiredQual'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['RequiredQual'].split()))

        averaged_score = (title_similarity + jd_similarity + jr_similarity + rq_similarity) / 4.0
        job_dissimilarity_d2v_df = job_dissimilarity_d2v_df.append({'index': job1_idx, 'similar-job': job2_idx, 'dissimilar-score': (1-averaged_score)},ignore_index=True)

# %%
job_dissimilarity_d2v_df_sorted = job_dissimilarity_d2v_df.sort_values(by=['index', 'dissimilar-score'], ascending=[True, True])

# %%
job_dissimilarity_d2v_df_sorted.head(10)
# Out:
#      index  similar-job  dissimilar-score
# 0      0.0          0.0          0.007872
# 696    0.0        696.0          0.500684
# 941    0.0        941.0          0.720614
# 528    0.0        528.0          0.726391
# 491    0.0        491.0          0.728418
# 162    0.0        162.0          0.729573
# 536    0.0        536.0          0.730215
# 362    0.0        362.0          0.732440
# 859    0.0        859.0          0.732727
# 863    0.0        863.0          0.733301

# %%
# Show top 5 similar results to job - Chief Financial Officer
similar_jobs = job_dissimilarity_d2v_df_sorted.loc[job_dissimilarity_d2v_df_sorted['index'] == 0].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                                                 Chief Financial Officer
# JobDescription              AMERIA Investment Consulting Company is seekin...
# RequiredQual                To perform this job successfully, an\nindividu...
# JobRequirment               - Supervises financial management and administ...
# JobDescription_token        [ameria, invest, consult, compani, seek, chief...
# RequiredQual_token          [to, perform, job, success, individu, must, ab...
# JobRequirment_token         [supervis, financi, manag, administr, staff, i...
# JobDescription_token_str    ameria invest consult compani seek chief finan...
# RequiredQual_token_str      to perform job success individu must abl perfo...
# JobRequirment_token_str     supervis financi manag administr staff includ ...
# RequiredQual_keywords       essential duty accepted accounting principles ...
# JobDescription_keywords     administrative functions complex staff assista...
# JobRequirment_keywords      financial management administrative staff assi...
# Name: 0, dtype: object
# Title                                                 Chief Financial Officer
# JobDescription              Cascade Capital Holdings CJSC is looking for a...
# RequiredQual                - A university degree in the relevant field. A...
# JobRequirment               - Create and oversee a financial reporting sys...
# JobDescription_token        [cascad, capit, hold, cjsc, look, motiv, self-...
# RequiredQual_token          [a, univers, degre, relev, field, acca/cpa/cfa...
# JobRequirment_token         [creat, overse, financi, report, system, inclu...
# JobDescription_token_str    cascad capit hold cjsc look motiv self-driven ...
# RequiredQual_token_str      a univers degre relev field acca/cpa/cfa/mba a...
# JobRequirment_token_str     creat overse financi report system includ seve...
# RequiredQual_keywords
# JobDescription_keywords
# JobRequirment_keywords
# Name: 697, dtype: object
# Title                                                            Trade Agents
# JobDescription              Valletta LLC is looking for experienced Trade ...
# RequiredQual                - Excellent communication skills;\n- Previous ...
# JobRequirment               - Sell fast moving consumer goods;\n- Provide ...
# JobDescription_token        [valletta, llc, look, experienc, trade, agent,...
# RequiredQual_token          [excel, commun, skill, previou, experi, sale, ...
# JobRequirment_token         [sell, fast, move, consum, good, provid, produ...
# JobDescription_token_str    valletta llc look experienc trade agent respon...
# RequiredQual_token_str      excel commun skill previou experi sale market ...
# JobRequirment_token_str     sell fast move consum good provid product info...
# RequiredQual_keywords       degree in business/ language degree in busines...
# JobDescription_keywords     several employees international clients techni...
# JobRequirment_keywords      Country contact incoming orders their correctn...
# Name: 942, dtype: object
# Title                                                 Economic Policy Advisor
# JobDescription              Publishing the Armenian Trends quarterly perio...
# RequiredQual                - University degree in the field of Economics,...
# JobRequirment               - Work on different sections of the periodical...
# JobDescription_token            [publish, armenian, trend, quarterli, period]
# RequiredQual_token          [univers, degre, field, econom, financ, manag,...
# JobRequirment_token         [work, differ, section, period, produc, edit, ...
# JobDescription_token_str              publish armenian trend quarterli period
# RequiredQual_token_str      univers degre field econom financ manag statis...
# JobRequirment_token_str     work differ section period produc edit articl ...
# RequiredQual_keywords       3-year work experience 3-year work experience ...
# JobDescription_keywords     Overall control management of company operatio...
# JobRequirment_keywords      his absence sales strategy maintain relationsh...
# Name: 529, dtype: object
# Title                                                Administrative Assistant
# JobDescription              The incumbent, under supervision of the Missio...
# RequiredQual                - Higher education in corresponding field.\n- ...
# JobRequirment               - Preparation of various administrative docume...
# JobDescription_token        [the, incumb, supervis, mission, administr, ca...
# RequiredQual_token          [higher, educ, correspond, field, relev, work,...
# JobRequirment_token         [prepar, variou, administr, document, contract...
# JobDescription_token_str    the incumb supervis mission administr carri ad...
# RequiredQual_token_str      higher educ correspond field relev work experi...
# JobRequirment_token_str     prepar variou administr document contract orde...
# RequiredQual_keywords       hospitable personality excellent command Armen...
# JobDescription_keywords     restaurant supervisors main function quest sat...
# JobRequirment_keywords      successful marketing plan successful marketing...
# Name: 492, dtype: object
# Title                                                       Project Assistant
# JobDescription              The Counterpart International (CPI) Office in ...
# RequiredQual                - University degree and/or professional experi...
# JobRequirment               Under supervision of the Project Director the\...
# JobDescription_token        [the, counterpart, intern, cpi, offic, yerevan...
# RequiredQual_token          [univers, degre, and/or, profession, experi, c...
# JobRequirment_token         [under, supervis, project, director, incumb, p...
# JobDescription_token_str    the counterpart intern cpi offic yerevan invit...
# RequiredQual_token_str      univers degre and/or profession experi commun ...
# JobRequirment_token_str     under supervis project director incumb perform...
# RequiredQual_keywords       Formal education western accounting practices ...
# JobDescription_keywords           invites applications Armenian professionals
# JobRequirment_keywords      following tasks financial aspects Prepare budg...
# Name: 163, dtype: object

# %%
# Show top 5 similar results to job - Intern
similar_jobs = job_dissimilarity_d2v_df_sorted.loc[job_dissimilarity_d2v_df_sorted['index'] == 1].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                       Full-time Community Connections Intern (paid i...
# JobDescription                                                            nan
# RequiredQual                - Bachelor's Degree; Master's is preferred;\n-...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [bachelor, 's, degre, master, 's, prefer, exce...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      bachelor 's degre master 's prefer excel skill...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       Excellent skills Armenian languages Armenian t...
# JobDescription_keywords
# JobRequirment_keywords
# Name: 1, dtype: object
# Title                                  Administrative and Programmatic Intern
# JobDescription                                                            nan
# RequiredQual                - Fluency in English and Armenian;\n- Good com...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [fluenci, english, armenian, good, commun, ski...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      fluenci english armenian good commun skill abi...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       analytical skills make recommendations present...
# JobDescription_keywords     area of car service area of car service car se...
# JobRequirment_keywords      financial matters strategic plans Marketing da...
# Name: 125, dtype: object
# Title                                  Administrative and Programmatic Intern
# JobDescription                                                            nan
# RequiredQual                - Fluency in English and Armenian;\n- Good com...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [fluenci, english, armenian, good, commun, ski...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      fluenci english armenian good commun skill abi...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       financial sector Computer skills organizationa...
# JobDescription_keywords
# JobRequirment_keywords      petty cash account petty cash account cash acc...
# Name: 127, dtype: object
# Title                                                              Programmer
# JobDescription                                                            nan
# RequiredQual                - Work experience of at least two years; \n- K...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [work, experi, least, two, year, knowledg, vis...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      work experi least two year knowledg visual stu...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords                     Work experience previous experience
# JobDescription_keywords
# JobRequirment_keywords
# Name: 35, dtype: object
# Title                                              ASP.NET (C#) Web Developer
# JobDescription                                                            nan
# RequiredQual                - Minimum 2 years experience in WEB programmin...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [minimum, 2, year, experi, web, program, datab...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      minimum 2 year experi web program databas deve...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       practical experience relevant field translatio...
# JobDescription_keywords     day to day operations day to day operations da...
# JobRequirment_keywords      Client liaison client servicing Document prepa...
# Name: 637, dtype: object
# Title                                                            Web designer
# JobDescription                                                            nan
# RequiredQual                - Proficient in  Photoshop, Flash (Action scri...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [profici, photoshop, flash, action, script, dr...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      profici photoshop flash action script dreamwea...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       university degree related subjects years of ex...
# JobDescription_keywords     Seniors who take part part in audit projects p...
# JobRequirment_keywords
# Name: 561, dtype: object

# %%
# Show top 5 similar results to job - Country Coordinator
similar_jobs = job_dissimilarity_d2v_df_sorted.loc[job_dissimilarity_d2v_df_sorted['index'] == 2].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                                                     Country Coordinator
# JobDescription              Public outreach and strengthening of a growing...
# RequiredQual                - Degree in environmentally related field, or ...
# JobRequirment               - Working with the Country Director to provide...
# JobDescription_token        [public, outreach, strengthen, grow, network, ...
# RequiredQual_token          [degre, environment, relat, field, 5, year, re...
# JobRequirment_token         [work, countri, director, provid, environment,...
# JobDescription_token_str    public outreach strengthen grow network enviro...
# RequiredQual_token_str      degre environment relat field 5 year relev exp...
# JobRequirment_token_str     work countri director provid environment infor...
# RequiredQual_keywords       related field relevant experience written flue...
# JobDescription_keywords     Public outreach growing network international ...
# JobRequirment_keywords      environmental information general public elect...
# Name: 2, dtype: object
# Title                        Armenian-Russian LanguageTranslator/ Interpreter
# JobDescription              A1+ TV Company is looking for qualified transl...
# RequiredQual                - BA or MA in linguistics;\n- Knowledge of MS ...
# JobRequirment               Translating news, articles for the web site of...
# JobDescription_token        [a1+, tv, compani, look, qualifi, translat, tr...
# RequiredQual_token           [ba, ma, linguist, knowledg, ms, word, internet]
# JobRequirment_token         [translat, news, articl, web, site, a1+, tv, c...
# JobDescription_token_str    a1+ tv compani look qualifi translat translat ...
# RequiredQual_token_str               ba ma linguist knowledg ms word internet
# JobRequirment_token_str          translat news articl web site a1+ tv compani
# RequiredQual_keywords
# JobDescription_keywords     TV Company qualified translators doing transla...
# JobRequirment_keywords                              Translating news web site
# Name: 889, dtype: object
# Title                                                              Chief Cook
# JobDescription              Committed person, to fulfil the position of Ch...
# RequiredQual                    6th grade Cook, knowledge of European cuisine
# JobRequirment                            To prepare Italian and European food
# JobDescription_token             [commit, person, fulfil, posit, chief, cook]
# RequiredQual_token             [6th, grade, cook, knowledg, european, cuisin]
# JobRequirment_token                     [to, prepar, italian, european, food]
# JobDescription_token_str                commit person fulfil posit chief cook
# RequiredQual_token_str                6th grade cook knowledg european cuisin
# JobRequirment_token_str                       to prepar italian european food
# RequiredQual_keywords                                     Excellent knowledge
# JobDescription_keywords         communication between customers travel agents
# JobRequirment_keywords
# Name: 435, dtype: object
# Title                                              Chemist - Organic/ Polymer
# JobDescription              H2 ECOnomy is seeking qualified candidate to f...
# RequiredQual                - Advanced degree in chemistry;\n- Knowledge o...
# JobRequirment               Work with members of scientific team to develo...
# JobDescription_token        [h2, economi, seek, qualifi, candid, fill, pos...
# RequiredQual_token          [advanc, degre, chemistri, knowledg, armenian,...
# JobRequirment_token         [work, member, scientif, team, develop, prepar...
# JobDescription_token_str    h2 economi seek qualifi candid fill posit chem...
# RequiredQual_token_str      advanc degre chemistri knowledg armenian russi...
# JobRequirment_token_str      work member scientif team develop prepar membran
# RequiredQual_keywords       Secondary education English language Formal tr...
# JobDescription_keywords           invites applications Armenian professionals
# JobRequirment_keywords      following tasks high quality written translati...
# Name: 103, dtype: object
# Title                                                      Web Design Trainer
# JobDescription              Individual is looking for a Web Design and MS ...
# RequiredQual                - HTML, PHP, MySQL, MS Access  knowledge is re...
# JobRequirment               The following training courses must be given:\...
# JobDescription_token        [individu, look, web, design, ms, access, trai...
# RequiredQual_token          [html, php, mysql, ms, access, knowledg, requi...
# JobRequirment_token         [the, follow, train, cours, must, given, web, ...
# JobDescription_token_str           individu look web design ms access trainer
# RequiredQual_token_str      html php mysql ms access knowledg requir exper...
# JobRequirment_token_str     the follow train cours must given web design h...
# RequiredQual_keywords       medical education qualification of doctor func...
# JobDescription_keywords
# JobRequirment_keywords      instrumental examination examination of patien...
# Name: 363, dtype: object
# Title                                                        AutoCAD Operator
# JobDescription              Yerevan Brandy Company is seeking qualified\nc...
# RequiredQual                - Higher technical education (qualification of...
# JobRequirment               Drawing works in Engineering and Maintenance\n...
# JobDescription_token        [yerevan, brandi, compani, seek, qualifi, cand...
# RequiredQual_token          [higher, technic, educ, qualif, engin, desir, ...
# JobRequirment_token                      [draw, work, engin, mainten, depart]
# JobDescription_token_str    yerevan brandi compani seek qualifi candid fil...
# RequiredQual_token_str      higher technic educ qualif engin desir excel k...
# JobRequirment_token_str                        draw work engin mainten depart
# RequiredQual_keywords       Advanced degree degree in chemistry English la...
# JobDescription_keywords                                   qualified candidate
# JobRequirment_keywords                      scientific team prepare membranes
# Name: 102, dtype: object

# %% [markdown]
# #### Using only the keywords

# %%
# iterate through each row vs rest of rows to calculate DIS-similarity

job_dissimilarity_d2v_df = pd.DataFrame(columns=['index', 'similar-job', 'dissimilar-score'])

for job1_idx in range(3):  # rows
    for job2_idx in range(1000):
        title_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['Title'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['Title'].split()))
        jd_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['JobDescription_keywords'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['JobDescription_keywords'].split()))
        jr_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['JobRequirment_keywords'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['JobRequirment_keywords'].split()))
        rq_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['RequiredQual_keywords'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['RequiredQual_keywords'].split()))

        averaged_score = (title_similarity + jd_similarity + jr_similarity + rq_similarity) / 4.0
        job_dissimilarity_d2v_df = job_dissimilarity_d2v_df.append({'index': job1_idx, 'similar-job': job2_idx, 'dissimilar-score': (1-averaged_score)},ignore_index=True)

# %%
job_dissimilarity_d2v_df_sorted = job_dissimilarity_d2v_df.sort_values(by=['index', 'dissimilar-score'], ascending=[True, True])

# %%
# Show top 5 similar results to job - Chief Financial Officer
similar_jobs = job_dissimilarity_d2v_df_sorted.loc[job_dissimilarity_d2v_df_sorted['index'] == 0].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                                                 Chief Financial Officer
# JobDescription              AMERIA Investment Consulting Company is seekin...
# RequiredQual                To perform this job successfully, an\nindividu...
# JobRequirment               - Supervises financial management and administ...
# JobDescription_token        [ameria, invest, consult, compani, seek, chief...
# RequiredQual_token          [to, perform, job, success, individu, must, ab...
# JobRequirment_token         [supervis, financi, manag, administr, staff, i...
# JobDescription_token_str    ameria invest consult compani seek chief finan...
# RequiredQual_token_str      to perform job success individu must abl perfo...
# JobRequirment_token_str     supervis financi manag administr staff includ ...
# RequiredQual_keywords       essential duty accepted accounting principles ...
# JobDescription_keywords     administrative functions complex staff assista...
# JobRequirment_keywords      financial management administrative staff assi...
# Name: 0, dtype: object
# Title                                                 Chief Financial Officer
# JobDescription              Cascade Capital Holdings CJSC is looking for a...
# RequiredQual                - A university degree in the relevant field. A...
# JobRequirment               - Create and oversee a financial reporting sys...
# JobDescription_token        [cascad, capit, hold, cjsc, look, motiv, self-...
# RequiredQual_token          [a, univers, degre, relev, field, acca/cpa/cfa...
# JobRequirment_token         [creat, overse, financi, report, system, inclu...
# JobDescription_token_str    cascad capit hold cjsc look motiv self-driven ...
# RequiredQual_token_str      a univers degre relev field acca/cpa/cfa/mba a...
# JobRequirment_token_str     creat overse financi report system includ seve...
# RequiredQual_keywords
# JobDescription_keywords
# JobRequirment_keywords
# Name: 697, dtype: object
# Title                                                       Marketing Manager
# JobDescription              Marketing Manager manages the company's market...
# RequiredQual                - University degree; \n- Excellent oral and wr...
# JobRequirment               - Supervise marketing staff, including assigni...
# JobDescription_token        [market, manag, manag, compani, 's, market, pr...
# RequiredQual_token          [univers, degre, excel, oral, write, skill, ar...
# JobRequirment_token         [supervis, market, staff, includ, assign, resp...
# JobDescription_token_str    market manag manag compani 's market pr functi...
# RequiredQual_token_str      univers degre excel oral write skill armenian ...
# JobRequirment_token_str     supervis market staff includ assign respons re...
# RequiredQual_keywords       relevant field writing skills English language...
# JobDescription_keywords                                    seeking applicants
# JobRequirment_keywords      project coordinator coordinator for workforce ...
# Name: 864, dtype: object
# Title                                                           Sales Manager
# JobDescription              On behalf of its partner, Ameria CJSC is seeki...
# RequiredQual                - University degree; \n- Excellent oral and wr...
# JobRequirment               - Supervise sales and distribution, including ...
# JobDescription_token        [on, behalf, partner, ameria, cjsc, seek, appl...
# RequiredQual_token          [univers, degre, excel, oral, write, skill, ar...
# JobRequirment_token         [supervis, sale, distribut, includ, assign, re...
# JobDescription_token_str    on behalf partner ameria cjsc seek applic posi...
# RequiredQual_token_str      univers degre excel oral write skill armenian ...
# JobRequirment_token_str     supervis sale distribut includ assign respons ...
# RequiredQual_keywords       relevant field writing skills English language...
# JobDescription_keywords                                    seeking applicants
# JobRequirment_keywords      cluster development activities cluster develop...
# Name: 857, dtype: object
# Title                                                Administrative Assistant
# JobDescription              To provide administrative assistance to Heifer...
# RequiredQual                - Higher education;\n- Strong Armenian, Russia...
# JobRequirment               - Ensure quality translations of written docum...
# JobDescription_token        [to, provid, administr, assist, heifer, caucas...
# RequiredQual_token          [higher, educ, strong, armenian, russian, engl...
# JobRequirment_token         [ensur, qualiti, translat, written, document, ...
# JobDescription_token_str    to provid administr assist heifer caucasu regi...
# RequiredQual_token_str      higher educ strong armenian russian english la...
# JobRequirment_token_str     ensur qualiti translat written document englis...
# RequiredQual_keywords       year of experience relevant field Strong comma...
# JobDescription_keywords
# JobRequirment_keywords      electromechanical infrastructure related sub c...
# Name: 975, dtype: object
# Title                             Global Fund ATM Implementation Unit Officer
# JobDescription              To work collaboratively with the Program imple...
# RequiredQual                The following knowledge, skills, and abilities...
# JobRequirment               - Participate in preparation of TORs, RFAs and...
# JobDescription_token        [to, work, collabor, program, implement, partn...
# RequiredQual_token          [the, follow, knowledg, skill, abil, may, acqu...
# JobRequirment_token         [particip, prepar, tor, rfa, document, through...
# JobDescription_token_str    to work collabor program implement partner pro...
# RequiredQual_token_str      the follow knowledg skill abil may acquir comb...
# JobRequirment_token_str     particip prepar tor rfa document throughout pr...
# RequiredQual_keywords       Driving license categories B years of experien...
# JobDescription_keywords     Driving office cars Driving office cars office...
# JobRequirment_keywords
# Name: 449, dtype: object

# %%
# Show top 5 similar results to job - Intern
similar_jobs = job_dissimilarity_d2v_df_sorted.loc[job_dissimilarity_d2v_df_sorted['index'] == 1].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                       Full-time Community Connections Intern (paid i...
# JobDescription                                                            nan
# RequiredQual                - Bachelor's Degree; Master's is preferred;\n-...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [bachelor, 's, degre, master, 's, prefer, exce...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      bachelor 's degre master 's prefer excel skill...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       Excellent skills Armenian languages Armenian t...
# JobDescription_keywords
# JobRequirment_keywords
# Name: 1, dtype: object
# Title                                                              Programmer
# JobDescription                                                            nan
# RequiredQual                - Work experience of at least two years; \n- K...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [work, experi, least, two, year, knowledg, vis...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      work experi least two year knowledg visual stu...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords                     Work experience previous experience
# JobDescription_keywords
# JobRequirment_keywords
# Name: 35, dtype: object
# Title                       Quality Assurance/ Health Systems Management A...
# JobDescription              Initiatives Inc. seeks a Quality Assurance/ He...
# RequiredQual                - MD or DrPH and experience/ qualifications in...
# JobRequirment               - Provides technical and managerial leadership...
# JobDescription_token        [initi, inc., seek, qualiti, assurance/, healt...
# RequiredQual_token          [md, drph, experience/, qualif, public, health...
# JobRequirment_token         [provid, technic, manageri, leadership, primar...
# JobDescription_token_str    initi inc. seek qualiti assurance/ health syst...
# RequiredQual_token_str      md drph experience/ qualif public health healt...
# JobRequirment_token_str     provid technic manageri leadership primari hea...
# RequiredQual_keywords                                      Working experience
# JobDescription_keywords
# JobRequirment_keywords
# Name: 44, dtype: object
# Title                           Moderator of Electronic Bulletin and Web site
# JobDescription              - Collection and editing if the information on...
# RequiredQual                - Fluency in Armenian and Russian,\n- Excellen...
# JobRequirment                                                             nan
# JobDescription_token        [collect, edit, inform, violenc, women, armeni...
# RequiredQual_token          [fluenci, armenian, russian, excel, comput, ed...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str    collect edit inform violenc women armenia coll...
# RequiredQual_token_str       fluenci armenian russian excel comput edit skill
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords                     Excellent knowledge Work experience
# JobDescription_keywords
# JobRequirment_keywords
# Name: 481, dtype: object
# Title                                                          Web Programmer
# JobDescription              Under general supervision, formulates programm...
# RequiredQual                - Strong knowledge of PHP, MySQL, HTM/HTML, Ja...
# JobRequirment               - Participates in the overall programming of t...
# JobDescription_token        [under, gener, supervis, formul, program, stra...
# RequiredQual_token          [strong, knowledg, php, mysql, htm/html, javas...
# JobRequirment_token         [particip, overal, program, web, site, maintai...
# JobDescription_token_str    under gener supervis formul program strategi i...
# RequiredQual_token_str      strong knowledg php mysql htm/html javascript ...
# JobRequirment_token_str     particip overal program web site maintain site...
# RequiredQual_keywords       years experience experience in WEB programming...
# JobDescription_keywords
# JobRequirment_keywords
# Name: 636, dtype: object
# Title                       Assistant in Management Advisory Services And ...
# JobDescription                                                            nan
# RequiredQual                - University degree preferably in Business Adm...
# JobRequirment               - Translation, editing, formatting, and printi...
# JobDescription_token                                                    [nan]
# RequiredQual_token          [univers, degre, prefer, busi, administr, econ...
# JobRequirment_token         [translat, edit, format, print, armenian, engl...
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      univers degre prefer busi administr econom exc...
# JobRequirment_token_str     translat edit format print armenian english ru...
# RequiredQual_keywords                                               year work
# JobDescription_keywords
# JobRequirment_keywords
# Name: 592, dtype: object

# %%
# Show top 5 similar results to job - Coordinator
similar_jobs = job_dissimilarity_d2v_df_sorted.loc[job_dissimilarity_d2v_df_sorted['index'] == 2].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                                                     Country Coordinator
# JobDescription              Public outreach and strengthening of a growing...
# RequiredQual                - Degree in environmentally related field, or ...
# JobRequirment               - Working with the Country Director to provide...
# JobDescription_token        [public, outreach, strengthen, grow, network, ...
# RequiredQual_token          [degre, environment, relat, field, 5, year, re...
# JobRequirment_token         [work, countri, director, provid, environment,...
# JobDescription_token_str    public outreach strengthen grow network enviro...
# RequiredQual_token_str      degre environment relat field 5 year relev exp...
# JobRequirment_token_str     work countri director provid environment infor...
# RequiredQual_keywords       related field relevant experience written flue...
# JobDescription_keywords     Public outreach growing network international ...
# JobRequirment_keywords      environmental information general public elect...
# Name: 2, dtype: object
# Title                                                         Product Manager
# JobDescription              We are looking for an experienced Software Pro...
# RequiredQual                - Software or computer related university degr...
# JobRequirment               - Conduct market research about existing produ...
# JobDescription_token           [we, look, experienc, softwar, product, manag]
# RequiredQual_token          [softwar, comput, relat, univers, degre, 1+, y...
# JobRequirment_token         [conduct, market, research, exist, product, de...
# JobDescription_token_str              we look experienc softwar product manag
# RequiredQual_token_str      softwar comput relat univers degre 1+ year exp...
# JobRequirment_token_str     conduct market research exist product develop ...
# RequiredQual_keywords       Russian languages working knowledge English la...
# JobDescription_keywords
# JobRequirment_keywords      PC operator administrative support routine wor...
# Name: 845, dtype: object
# Title                                                     Archhitect Designer
# JobDescription              We are looking for an Architect Desiner to wor...
# RequiredQual                - Higher education, \n- Relevant work experien...
# JobRequirment                            - Design furniture\n- Assure quality
# JobDescription_token        [we, look, architect, desin, work, furnitur, i...
# RequiredQual_token          [higher, educ, relev, work, experi, appropri, ...
# JobRequirment_token                        [design, furnitur, assur, qualiti]
# JobDescription_token_str       we look architect desin work furnitur industri
# RequiredQual_token_str      higher educ relev work experi appropri comput ...
# JobRequirment_token_str                         design furnitur assur qualiti
# RequiredQual_keywords       Previous experience Excellent interpersonal co...
# JobDescription_keywords     foreign businessman experienced person his son...
# JobRequirment_keywords      selected person forth grade grade of level lev...
# Name: 212, dtype: object
# Title                                                          Microbiologist
# JobDescription              We are seeking a Microbiologist to work for an...
# RequiredQual                - Higher education in relevant field;\n- Work ...
# JobRequirment               - Control on raw materials and final products;...
# JobDescription_token        [we, seek, microbiologist, work, industri, ent...
# RequiredQual_token          [higher, educ, relev, field, work, experi, rel...
# JobRequirment_token         [control, raw, materi, final, product, sanitar...
# JobDescription_token_str       we seek microbiologist work industri enterpris
# RequiredQual_token_str        higher educ relev field work experi relav field
# JobRequirment_token_str     control raw materi final product sanitari cont...
# RequiredQual_keywords       Experience in design developing software produ...
# JobDescription_keywords     take part part in design execution of software...
# JobRequirment_keywords      Develop software systems Develop software syst...
# Name: 910, dtype: object
# Title                            Personal Assistant to the Executive Director
# JobDescription              The jobholder will be responsible for assistin...
# RequiredQual                - A degree and practical experience in a relev...
# JobRequirment               - Translation,\n- Client liaison and client se...
# JobDescription_token        [the, jobhold, respons, assist, execut, direct...
# RequiredQual_token          [a, degre, practic, experi, relev, field, incl...
# JobRequirment_token         [translat, client, liaison, client, servic, do...
# JobDescription_token_str    the jobhold respons assist execut director day...
# RequiredQual_token_str      a degre practic experi relev field includ tran...
# JobRequirment_token_str     translat client liaison client servic document...
# RequiredQual_keywords       detailed information required qualifications f...
# JobDescription_keywords     execution of software tools execution of softw...
# JobRequirment_keywords      maintain software systems maintain software sy...
# Name: 638, dtype: object
# Title                                                               Volunteer
# JobDescription              We are seeking university students/ recent gra...
# RequiredQual                - Fluency in Armenian, Russian and English\n- ...
# JobRequirment               - Assist CENN Armenia Country Coordinator with...
# JobDescription_token        [we, seek, univers, students/, recent, graduat...
# RequiredQual_token          [fluenci, armenian, russian, english, good, co...
# JobRequirment_token         [assist, cenn, armenia, countri, coordin, admi...
# JobDescription_token_str    we seek univers students/ recent graduat energ...
# RequiredQual_token_str      fluenci armenian russian english good communic...
# JobRequirment_token_str     assist cenn armenia countri coordin adminstr t...
# RequiredQual_keywords       ideal candidate regional language skills regio...
# JobDescription_keywords          supervision of CNFAs supports implementation
# JobRequirment_keywords      country field offices country field offices fi...
# Name: 567, dtype: object

# %%
# iterate through each row vs rest of rows to calculate DIS-similarity

job_dissimilarity_d2v_df = pd.DataFrame(columns=['index', 'similar-job', 'dissimilar-score'])

for job1_idx in range(3):  # rows
    for job2_idx in range(1000):
        title_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['Title'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['Title'].split()))
        jd_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['JobDescription'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['JobDescription'].split()))
        jr_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['JobRequirment'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['JobRequirment'].split()))
        rq_similarity = 1- scipy.spatial.distance.cosine(d2vmodel.infer_vector(df_job_related.iloc[job1_idx]['RequiredQual'].split()), d2vmodel.infer_vector(df_job_related.iloc[job2_idx]['RequiredQual'].split()))

        averaged_score = (title_similarity*0.9 + jd_similarity*0.3 + jr_similarity*0.3 + rq_similarity*0.3) / 4.0
        job_dissimilarity_d2v_df = job_dissimilarity_d2v_df.append({'index': job1_idx, 'similar-job': job2_idx, 'dissimilar-score': (1-averaged_score)},ignore_index=True)

# %%
job_dissimilarity_d2v_df_sorted = job_dissimilarity_d2v_df.sort_values(by=['index', 'dissimilar-score'], ascending=[True, True])

# %%
job_dissimilarity_d2v_df_sorted.head(10)
# Out:
#      index  similar-job  dissimilar-score
# 0      0.0          0.0          0.552287
# 696    0.0        696.0          0.699992
# 314    0.0        314.0          0.904818
# 859    0.0        859.0          0.905493
# 346    0.0        346.0          0.906263
# 427    0.0        427.0          0.907035
# 925    0.0        925.0          0.908099
# 162    0.0        162.0          0.908832
# 860    0.0        860.0          0.909080
# 536    0.0        536.0          0.909420

# %%
# Show top 5 similar results to job - Chief Financial Officer
similar_jobs = job_dissimilarity_d2v_df_sorted.loc[job_dissimilarity_d2v_df_sorted['index'] == 0].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                                                 Chief Financial Officer
# JobDescription              AMERIA Investment Consulting Company is seekin...
# RequiredQual                To perform this job successfully, an\nindividu...
# JobRequirment               - Supervises financial management and administ...
# JobDescription_token        [ameria, invest, consult, compani, seek, chief...
# RequiredQual_token          [to, perform, job, success, individu, must, ab...
# JobRequirment_token         [supervis, financi, manag, administr, staff, i...
# JobDescription_token_str    ameria invest consult compani seek chief finan...
# RequiredQual_token_str      to perform job success individu must abl perfo...
# JobRequirment_token_str     supervis financi manag administr staff includ ...
# RequiredQual_keywords       essential duty accepted accounting principles ...
# JobDescription_keywords     administrative functions complex staff assista...
# JobRequirment_keywords      financial management administrative staff assi...
# Name: 0, dtype: object
# Title                                                 Chief Financial Officer
# JobDescription              Cascade Capital Holdings CJSC is looking for a...
# RequiredQual                - A university degree in the relevant field. A...
# JobRequirment               - Create and oversee a financial reporting sys...
# JobDescription_token        [cascad, capit, hold, cjsc, look, motiv, self-...
# RequiredQual_token          [a, univers, degre, relev, field, acca/cpa/cfa...
# JobRequirment_token         [creat, overse, financi, report, system, inclu...
# JobDescription_token_str    cascad capit hold cjsc look motiv self-driven ...
# RequiredQual_token_str      a univers degre relev field acca/cpa/cfa/mba a...
# JobRequirment_token_str     creat overse financi report system includ seve...
# RequiredQual_keywords
# JobDescription_keywords
# JobRequirment_keywords
# Name: 697, dtype: object
# Title                                            Global Fund PRIU Team Leader
# JobDescription              The Principal Recipient Implementation Unit (P...
# RequiredQual                General: \nThe successful candidate will posse...
# JobRequirment               As a senior member of the PRIU and reporting t...
# JobDescription_token        [the, princip, recipi, implement, unit, priu, ...
# RequiredQual_token          [gener, the, success, candid, possess, strong,...
# JobRequirment_token         [as, senior, member, priu, report, oper, direc...
# JobDescription_token_str    the princip recipi implement unit priu team le...
# RequiredQual_token_str      gener the success candid possess strong broad ...
# JobRequirment_token_str     as senior member priu report oper director tl ...
# RequiredQual_keywords       university degree precise sciences attentive p...
# JobDescription_keywords     retail business activities retail business act...
# JobRequirment_keywords
# Name: 315, dtype: object
# Title                                                        Chief Accountant
# JobDescription              Chief Accountant will be supervised by Financi...
# RequiredQual                - University degree in Accounting/ Finance;\n-...
# JobRequirment               - Preparate monthly and annual financial and t...
# JobDescription_token        [chief, account, supervis, financi, director, ...
# RequiredQual_token          [univers, degre, accounting/, financ, russian,...
# JobRequirment_token         [prepar, monthli, annual, financi, tax, report...
# JobDescription_token_str      chief account supervis financi director compani
# RequiredQual_token_str      univers degre accounting/ financ russian armen...
# JobRequirment_token_str     prepar monthli annual financi tax report tax m...
# RequiredQual_keywords       writing skills English languages Good working ...
# JobDescription_keywords     Management Consultant multiple projects projec...
# JobRequirment_keywords      Elaborate business plans Elaborate business pl...
# Name: 860, dtype: object
# Title                                                     Executive Secretary
# JobDescription              We are seeking a high-qualified Executive Secr...
# RequiredQual                - University degree in languages \n- Minimum o...
# JobRequirment               - Provides high- level secretarial and adminis...
# JobDescription_token        [we, seek, high-qualifi, execut, secretari, re...
# RequiredQual_token          [univers, degre, languag, minimum, least, 5, y...
# JobRequirment_token         [provid, high-, level, secretari, administr, s...
# JobDescription_token_str    we seek high-qualifi execut secretari report d...
# RequiredQual_token_str      univers degre languag minimum least 5 year exp...
# JobRequirment_token_str     provid high- level secretari administr support...
# RequiredQual_keywords            considerable experience delivering trainings
# JobDescription_keywords     invites business trainers invites business tra...
# JobRequirment_keywords                                      Training delivery
# Name: 347, dtype: object
# Title                                      Secretary/Administrative Assistant
# JobDescription                Provide secretarial and administrative support.
# RequiredQual                - Relevant university degree Yerevan State Uni...
# JobRequirment               - Establish, maintain, update and overall proc...
# JobDescription_token                  [provid, secretari, administr, support]
# RequiredQual_token          [relev, univers, degre, yerevan, state, univer...
# JobRequirment_token         [establish, maintain, updat, overal, process, ...
# JobDescription_token_str                   provid secretari administr support
# RequiredQual_token_str      relev univers degre yerevan state univers inst...
# JobRequirment_token_str     establish maintain updat overal process corres...
# RequiredQual_keywords                  professional firms individual trainers
# JobDescription_keywords     professional firms individual trainers provisi...
# JobRequirment_keywords      following core elements following core element...
# Name: 428, dtype: object

# %%
# Show top 5 similar results to job - Intern
similar_jobs = job_dissimilarity_d2v_df_sorted.loc[job_dissimilarity_d2v_df_sorted['index'] == 1].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                       Full-time Community Connections Intern (paid i...
# JobDescription                                                            nan
# RequiredQual                - Bachelor's Degree; Master's is preferred;\n-...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [bachelor, 's, degre, master, 's, prefer, exce...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      bachelor 's degre master 's prefer excel skill...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       Excellent skills Armenian languages Armenian t...
# JobDescription_keywords
# JobRequirment_keywords
# Name: 1, dtype: object
# Title                                                              Programmer
# JobDescription                                                            nan
# RequiredQual                - Work experience of at least two years; \n- K...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [work, experi, least, two, year, knowledg, vis...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      work experi least two year knowledg visual stu...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords                     Work experience previous experience
# JobDescription_keywords
# JobRequirment_keywords
# Name: 35, dtype: object
# Title                                  Administrative and Programmatic Intern
# JobDescription                                                            nan
# RequiredQual                - Fluency in English and Armenian;\n- Good com...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [fluenci, english, armenian, good, commun, ski...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      fluenci english armenian good commun skill abi...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       financial sector Computer skills organizationa...
# JobDescription_keywords
# JobRequirment_keywords      petty cash account petty cash account cash acc...
# Name: 127, dtype: object
# Title                                  Administrative and Programmatic Intern
# JobDescription                                                            nan
# RequiredQual                - Fluency in English and Armenian;\n- Good com...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [fluenci, english, armenian, good, commun, ski...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      fluenci english armenian good commun skill abi...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       analytical skills make recommendations present...
# JobDescription_keywords     area of car service area of car service car se...
# JobRequirment_keywords      financial matters strategic plans Marketing da...
# Name: 125, dtype: object
# Title                                              ASP.NET (C#) Web Developer
# JobDescription                                                            nan
# RequiredQual                - Minimum 2 years experience in WEB programmin...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [minimum, 2, year, experi, web, program, datab...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      minimum 2 year experi web program databas deve...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       practical experience relevant field translatio...
# JobDescription_keywords     day to day operations day to day operations da...
# JobRequirment_keywords      Client liaison client servicing Document prepa...
# Name: 637, dtype: object
# Title                                                       Graphics Designer
# JobDescription                                                            nan
# RequiredQual                A degree within graphics and minimum 2 years\n...
# JobRequirment                                                             nan
# JobDescription_token                                                    [nan]
# RequiredQual_token          [a, degre, within, graphic, minimum, 2, year, ...
# JobRequirment_token                                                     [nan]
# JobDescription_token_str                                                  nan
# RequiredQual_token_str      a degre within graphic minimum 2 year relev wo...
# JobRequirment_token_str                                                   nan
# RequiredQual_keywords       Work experience Higher education high pressure...
# JobDescription_keywords
# JobRequirment_keywords      daily operations sells shop maintain relations...
# Name: 564, dtype: object

# %%
# Show top 5 similar results to job - Country Coordinator
similar_jobs = job_dissimilarity_d2v_df_sorted.loc[job_dissimilarity_d2v_df_sorted['index'] == 2].head(6)['similar-job'].tolist()

for job in similar_jobs:
    print(df_job_related.iloc[int(job)])
# Out:
# Title                                                     Country Coordinator
# JobDescription              Public outreach and strengthening of a growing...
# RequiredQual                - Degree in environmentally related field, or ...
# JobRequirment               - Working with the Country Director to provide...
# JobDescription_token        [public, outreach, strengthen, grow, network, ...
# RequiredQual_token          [degre, environment, relat, field, 5, year, re...
# JobRequirment_token         [work, countri, director, provid, environment,...
# JobDescription_token_str    public outreach strengthen grow network enviro...
# RequiredQual_token_str      degre environment relat field 5 year relev exp...
# JobRequirment_token_str     work countri director provid environment infor...
# RequiredQual_keywords       related field relevant experience written flue...
# JobDescription_keywords     Public outreach growing network international ...
# JobRequirment_keywords      environmental information general public elect...
# Name: 2, dtype: object
# Title                                                      Web Design Trainer
# JobDescription              Individual is looking for a Web Design and MS ...
# RequiredQual                - HTML, PHP, MySQL, MS Access  knowledge is re...
# JobRequirment               The following training courses must be given:\...
# JobDescription_token        [individu, look, web, design, ms, access, trai...
# RequiredQual_token          [html, php, mysql, ms, access, knowledg, requi...
# JobRequirment_token         [the, follow, train, cours, must, given, web, ...
# JobDescription_token_str           individu look web design ms access trainer
# RequiredQual_token_str      html php mysql ms access knowledg requir exper...
# JobRequirment_token_str     the follow train cours must given web design h...
# RequiredQual_keywords       medical education qualification of doctor func...
# JobDescription_keywords
# JobRequirment_keywords      instrumental examination examination of patien...
# Name: 363, dtype: object
# Title                                Precision Engineering Cluster Specialist
# JobDescription              Ameria CJSC is seeking highly qualified Precis...
# RequiredQual                - University degree in relevant field;\n- Exce...
# JobRequirment               - Provide ongoing support to cluster formation...
# JobDescription_token        [ameria, cjsc, seek, highli, qualifi, precis, ...
# RequiredQual_token          [univers, degre, relev, field, excel, oral, wr...
# JobRequirment_token         [provid, ongo, support, cluster, format, imple...
# JobDescription_token_str    ameria cjsc seek highli qualifi precis engin c...
# RequiredQual_token_str      univers degre relev field excel oral write ski...
# JobRequirment_token_str     provid ongo support cluster format implement p...
# RequiredQual_keywords       relevant field writing skills English language...
# JobDescription_keywords                                    seeking applicants
# JobRequirment_keywords      ongoing support cluster formation Provide supp...
# Name: 872, dtype: object
# Title                                                       Artist - Designer
# JobDescription              Antares Media Holding is looking for an experi...
# RequiredQual                - Specialized higher education;\n- At least 3 ...
# JobRequirment               - Work directly with the Director of the compa...
# JobDescription_token        [antar, media, hold, look, experienc, artist, ...
# RequiredQual_token          [special, higher, educ, at, least, 3, year, ex...
# JobRequirment_token         [work, directli, director, compani, one, hand,...
# JobDescription_token_str        antar media hold look experienc artist design
# RequiredQual_token_str      special higher educ at least 3 year experi sim...
# JobRequirment_token_str     work directli director compani one hand manag ...
# RequiredQual_keywords       selection criterion comprehensive information ...
# JobDescription_keywords     Performs secretary receptionist duties central...
# JobRequirment_keywords
# Name: 165, dtype: object
# Title                        Armenian-Russian LanguageTranslator/ Interpreter
# JobDescription              A1+ TV Company is looking for qualified transl...
# RequiredQual                - BA or MA in linguistics;\n- Knowledge of MS ...
# JobRequirment               Translating news, articles for the web site of...
# JobDescription_token        [a1+, tv, compani, look, qualifi, translat, tr...
# RequiredQual_token           [ba, ma, linguist, knowledg, ms, word, internet]
# JobRequirment_token         [translat, news, articl, web, site, a1+, tv, c...
# JobDescription_token_str    a1+ tv compani look qualifi translat translat ...
# RequiredQual_token_str               ba ma linguist knowledg ms word internet
# JobRequirment_token_str          translat news articl web site a1+ tv compani
# RequiredQual_keywords
# JobDescription_keywords     TV Company qualified translators doing transla...
# JobRequirment_keywords                              Translating news web site
# Name: 889, dtype: object
# Title                                                   Sales Clerk/ Referent
# JobDescription              "Digital Technologies" LLC is looking for a Sa...
# RequiredQual                - English, Armenian and Russian language skill...
# JobRequirment               - To welcome new clients;\n- Present informati...
# JobDescription_token        [``, digit, technolog, '', llc, look, sale, cl...
# RequiredQual_token          [english, armenian, russian, languag, skill, w...
# JobRequirment_token         [to, welcom, new, client, present, inform, off...
# JobDescription_token_str     `` digit technolog '' llc look sale clerk/ refer
# RequiredQual_token_str      english armenian russian languag skill written...
# JobRequirment_token_str     to welcom new client present inform offer good...
# RequiredQual_keywords       have experience international teaching methodo...
# JobDescription_keywords     community development culture competencies tra...
# JobRequirment_keywords
# Name: 149, dtype: object
